# %%
import pandas as pd

# %%
path_to_news = "./data/gdelt_crawled/gdelt_crawled/storm/clustered_news_all_country.csv"

# %%
df = pd.read_csv(path_to_news)

# %%
print(f"Columns: {df.columns}")
print(f"Number of entries: {len(df)}")
print(f"Number of unique titles: {df.title.nunique()}")
print(f"Number of clusters: {df.cluster_25_75.nunique()}")
print(f"Number of countries: {df.sourcecountry.nunique()}")
print(f"Number of domains: {df.domain.nunique()}")
# Out:
# Columns: Index(['Unnamed: 0', 'url', 'url_mobile', 'title', 'seendate', 'socialimage',
#        'domain', 'language', 'sourcecountry', 'start_date', 'end_date',
#        'cluster_25_75'],
#       dtype='object')
# Number of entries: 593437
# Number of unique titles: 373244
# Number of clusters: 2880
# Number of countries: 147
# Number of domains: 9314

# %%
df
# Out:
#         Unnamed: 0                                                url  \
# 0                1  https://www.echoroukonline.com/a-new-stab-by-t...
# 1                3  https://www.echoroukonline.com/algeria-hikes-g...
# 2                2  https://www.echoroukonline.com/sanchez-fails-t...
# 3                3  https://www.echoroukonline.com/colonial-nostal...
# 4                0  https://reliefweb.int/report/antigua-and-barbu...
# ...            ...                                                ...
# 593432           0  https://velveteenrabbi.blogs.com/blog/2022/06/...
# 593433           0  https://clubofmozambique.com/news/watch-the-cy...
# 593434           1  https://clubofmozambique.com/news/watch-severe...
# 593435           0  https://clubofmozambique.com/news/mozambique-t...
# 593436           0  https://clubofmozambique.com/news/mozambique-i...
#
#                                                url_mobile  \
# 0       https://www.echoroukonline.com/a-new-stab-by-t...
# 1       https://www.echoroukonline.com/algeria-hikes-g...
# 2       https://www.echoroukonline.com/sanchez-fails-t...
# 3       https://www.echoroukonline.com/colonial-nostal...
# 4                                                     NaN
# ...                                                   ...
# 593432                                                NaN
# 593433                                                NaN
# 593434                                                NaN
# 593435                                                NaN
# 593436                                                NaN
#
#                                                     title          seendate  \
# 0       A New Stab By The Moroccan Makhzen In Algeria ...  20210718T154500Z
# 1       Algeria Hikes Gas , Oil Supplies To Spain Amid...  20211117T210000Z
# 2       Sanchez Fails to Mobilize NATO Summit Against ...  20220701T223000Z
# 3       Colonial Nostalgia For Algeria Poisons The Fre...  20220629T180000Z
# 4       CCRIF Members in the Caribbean and Central Ame...  20210801T200000Z
# ...                                                   ...               ...
# 593432  Velveteen Rabbi : Land of Promise : Teachings ...  20220625T164500Z
# 593433  Watch :  The cyclone was devastating  – Daviz ...  20210125T170000Z
# 593434  Watch : Severe winds wreck homes , displace th...  20210125T180000Z
# 593435  Mozambique : Total wants 25 km security zone ;...  20210216T163000Z
# 593436  Mozambique : Imminent Tropical Storm – Emergen...  20220122T194500Z
#
#                                               socialimage  \
# 0       https://www.echoroukonline.com/wp-content/uplo...
# 1       https://www.echoroukonline.com/wp-content/uplo...
# 2       https://www.echoroukonline.com/wp-content/uplo...
# 3       https://www.echoroukonline.com/wp-content/uplo...
# 4       https://reliefweb.int/profiles/reliefweb/theme...
# ...                                                   ...
# 593432  https://velveteenrabbi.blogs.com/.a/6a00d8341c...
# 593433  https://clubofmozambique.com/wp-content/upload...
# 593434  https://clubofmozambique.com/wp-content/upload...
# 593435  https://clubofmozambique.com/wp-content/upload...
# 593436  https://clubofmozambique.com/wp-content/upload...
#
#                           domain language sourcecountry  start_date  \
# 0             echoroukonline.com  English       Algeria  2021-07-18
# 1             echoroukonline.com  English       Algeria  2021-11-17
# 2             echoroukonline.com  English       Algeria  2022-07-01
# 3             echoroukonline.com  English       Algeria  2022-06-29
# 4                  reliefweb.int  English         Syria  2021-08-01
# ...                          ...      ...           ...         ...
# 593432  velveteenrabbi.blogs.com  English    Mozambique  2022-06-25
# 593433      clubofmozambique.com  English    Mozambique  2021-01-25
# 593434      clubofmozambique.com  English    Mozambique  2021-01-25
# 593435      clubofmozambique.com  English    Mozambique  2021-02-16
# 593436      clubofmozambique.com  English    Mozambique  2022-01-22
#
#           end_date  cluster_25_75
# 0       2021-07-19            NaN
# 1       2021-11-18            NaN
# 2       2022-07-02            NaN
# 3       2022-06-30            NaN
# 4       2021-08-02            NaN
# ...            ...            ...
# 593432  2022-06-26            NaN
# 593433  2021-01-26            NaN
# 593434  2021-01-26            NaN
# 593435  2021-02-17            NaN
# 593436  2022-01-23          548.0
#
# [593437 rows x 12 columns]

# %%
df.title.nunique()
# Out:
# 373244

# %%
df.cluster_25_75.value_counts().plot()
# Out:
# <Axes: xlabel='cluster_25_75'>

# %%
df.loc[df['cluster_25_75'] == 2].start_date.unique()
# Out:
# array(['2021-07-07', '2021-07-05', '2021-07-06', '2021-07-08',
#        '2021-07-03', '2021-07-02', '2021-07-04', '2021-07-10',
#        '2021-07-09', '2021-06-30', '2021-07-23', '2021-07-01'],
#       dtype=object)

# %%
df.loc[df['cluster_25_75'] == 2].end_date.unique()
# Out:
# array(['2021-07-08', '2021-07-06', '2021-07-07', '2021-07-09',
#        '2021-07-04', '2021-07-03', '2021-07-05', '2021-07-11',
#        '2021-07-10', '2021-07-01', '2021-07-24', '2021-07-02'],
#       dtype=object)

# %%
df.loc[df['cluster_25_75'] == 2].title.unique()
# Out:
# array(['Elsa Weakens to a Tropical Storm as It Takes Aim at Florida',
#        'Storm Elsa Moving on Florida after Battering Cuba',
#        'Tropical Storm Elsa Could Hit Tampa Bay Region',
#        'Tropical Storm Elsa In Cuba , Eyes Florida Next',
#        'Tropical Storm Elsa May Hit Florida With  Life - Threatening  Storm Surge and Tornadoes',
#        'Storm Elsa regain hurricane strength as it batters Florida with heavy rains , winds and power outages',
#        'Tropical Storm Elsa hits Florida but weakened winds limit damage',
#        'Elsa strengthens into a hurricane as it heads to Gulf Coast',
#        'Elsa weakens to tropical storm as it threatens Florida coast',
#        'Elsa strengthens into hurricane as it heads to Gulf Coast',
#        'Storm Elsa path tracker LIVE - Tropical storm to hit Florida coast ANY TIME as hurricane & tornado threat declared',
#        'Tropical Storm Elsa poised to make landfall in Florida',
#        'Weakening Elsa makes landfall but Florida spared significant damage',
#        'Storm Elsa regains strength and becomes a HURRICANE',
#        'Tropical Storm Elsa makes landfall and batters Florida with 70mph winds as rescuers hunt for 9 missing in water',
#        'Tropical Storm Elsa : Cuba reels as storm moves towards Florida',
#        'Tropical Storm Elsa takes aim at Florida after passing Cuba',
#        'Tropical Storm Elsa gaining strength as it lashes Florida Keys',
#        'Tropical Storm Elsa approaches Florida after 180 , 000 evacuated in Cuba',
#        'Tropical Storm Elsa lashes Florida Keys as conditions worsen',
#        'Hurricane Elsa : Storm heads towards Haiti and the Dominican Republic on possible path to Cuba and Florida',
#        'Hurricane Elsa path tracker : Where will storm hit and will it reach Florida ? ',
#        'Storm Elsa has become a hurricane , the first of the season , and is barreling towards Florida',
#        'Storm Elsa : How is it evolving and how far is it from Florida ? ',
#        'Tropical storm Elsa batters Cuban and Florida coasts - Israel National News',
#        'Elsa strengthens to hurricane as it hovers off the coast of Florida',
#        'Tropical Storm Elsa hits Cuba as it heads towards Florida Keys',
#        'Elsa weakens to tropical storm , heads towards Florida Gulf coast',
#        'Tropical storm Elsa makes landfall in Cuba , on track to Florida',
#        'Tropical Storm Elsa skirts Key West , aims for Florida Gulf Coast',
#        'Storm Elsa moves over Florida Straits after battering Cuba',
#        'Tropical Storm Elsa , Back Over Water , Takes Aim at Florida',
#        'Tropical storm Elsa forms over Atlantic',
#        'Tropical Storm Elsa makes landfall on Florida Gulf Coast',
#        'Tropical storm Elsa brings heavy rains to Cuba - World News',
#        'So far , little impact for Florida growers following Hurricane Elsa',
#        'Tropical Storm Elsa strengthens into hurricane lashing Florida',
#        'US : Tropical storm Elsa rages through East Coast | News | DW',
#        'Storm Elsa Moving On Florida After Battering Cuba',
#        'Tropical Storm Elsa Weakens After Making Landfall In Florida',
#        'Tropical Storm Elsa wreaks havoc as it tears through the Caribbean',
#        'Storm Elsa strengthens into a hurricane as it hurtles towards Florida Gulf Coast',
#        'Elsa strengthens to hurricane and takes aims at Florida',
#        'USA News Headlines Today Live Updates : Tropical storm Elsa weakens , spares Florida of major damage',
#        'Tropical Storm Elsa becomes hurricane , expected to make landfall on Florida Gulf Coast',
#        'Elsa Strengthens To Hurricane , Takes Aims At Florida',
#        'Emergency declared for South Florida as tropical storm Elsa approaches',
#        'Emergency in S Florida as storm Elsa approaches',
#        'Hurricane Elsa Path : Tropical storm Elsa gaining strength , lashing Florida Keys | World News',
#        'Tropical Storm Elsa gaining strength , could become hurricane',
#        'Tropical storm Elsa set to exit Cuba , take aim at Florida',
#        'USA News Headlines Today Live Updates : Tropical storm Elsa gaining strength , lashing Florida Keys',
#        'Hurricane Elsa : Elsa strengthens into season first hurricane in Caribbean | World News',
#        'Emergency Declared For South Florida as Tropical Storm Elsa Approaches',
#        'Elsa Nears Hurricane Strength Once Again as Storm Intensifies Ahead of Florida Landfall',
#        'Tropical Storm Elsa a Stark Reminder to Be Prepared for the Atlantic Hurricane Season',
#        'Tropical Storm Elsa makes landfall Wednesday morning along Florida northern Gulf Coast',
#        'Tropical Storm Elsa making landfall in Florida',
#        'Tropical Storm Elsa nearing landfall along Florida Gulf coast : See track',
#        'Tropical Storm Elsa nears landfall along Florida west coast',
#        'Tropical Storm Elsa : Here What NYC Can Expect',
#        'Tropical Storm Elsa moves along Florida west coast , bringing flood , storm surge threat',
#        'Elsa storm to make Florida Gulf Coast landfall amid tropical warnings',
#        'FIRST ALERT : SC coast under tropical storm warning ahead of Elsa',
#        'Tropical Storm Elsa threatens NC , SC coasts with winds and rain . Here the forecast',
#        'Tropical Storm Warning in effect for SC as Elsa weakens over Florida',
#        'Tropical Storm Warning in effect for SC as Elsa heads to Georgia',
#        'Tropical Storm Elsa Makes Landfall in Florida',
#        'Tropical Storm Elsa : Storm Makes Landfall In Florida , Tropical Storm Watch Extended Up Coast To New Jersey',
#        'Tropical Storm Elsa weakens , spares Florida of major damage',
#        'Tropical Storm Elsa nears landfall in Florida , eyes East Coast with heavy rain , wind',
#        'Tropical Storm Elsa is moving along Florida coast . When and where will it make landfall ? ',
#        'Tropical Storm Elsa Makes Landfall In Florida : NPR',
#        'Tropical Storm Elsa makes landfall along Florida Gulf Coast',
#        'Elsa May Strengthen Back Into Hurricane As It Barrels Towards Florida',
#        'Elsa May Strengthen Back Into Hurricane As It Barrels Towards Florida | 97 . 3 and 103 . 3 The Bull ICONS',
#        'Elsa weakening in northern Florida after making landfall Wednesday morning',
#        'As Elsa nears landfall in Florida , North Carolina officials prepare for system to pass through as tropical storm :: WRAL . com',
#        'After strengthening to hurricane status , Elsa is back as a Tropical Storm | 98 . 7 The River',
#        'Tropical Storm Elsa : Track the storm path and possible impacts',
#        'Tropical Storm Elsa aims for Florida  Big Bend  :: WRAL . com',
#        'Tropical Storm Elsa Approaches Landfall Along Florida West Coast',
#        'Tropical Storm Elsa Has Made Landfall Along Florida Gulf Coast',
#        'Tropical Storm Elsa churns toward Florida Gulf Coast',
#        'Tropical Storm Elsa making landfall in Taylor County on Florida Gulf Coast',
#        'New forecast : Elsa still close to hurricane strength and is expected to become a hurricane tonight',
#        'Tropical Storm Elsa Makes Landfall Along Florida Gulf Coast',
#        'As Hurricane Elsa nears landfall in Florida , North Carolina officials prepare for system to pass through as tropical storm :: WRAL . com',
#        'Elsa near landfall in Florida , tropical storm watch extended west in NC :: WRAL . com',
#        'Elsa weakens to a tropical storm as it takes aim at Florida',
#        'Tropical Storm Elsa weakens , spares Florida major damage',
#        'Stars and Stripes - Tropical Storm Elsa makes landfall along Florida Gulf Coast',
#        'Elsa strengthens into Category 1 hurricane as it nears Florida :: WRAL . com',
#        'Tropical Storm Elsa weakens , spares Florida of major damage :: WRAL . com',
#        'Tropical Storm Elsa Makes Landfall In Florida Big Bend , With 65 MPH Winds',
#        'Tropical Storm Elsa Makes Landfall In Florida Big Bend , With 65 MPH Winds | 94 . 5 WFLA',
#        'Tropical Storm Elsa Makes Landfall In Florida Big Bend , With 65 MPH Winds | NewsRadio WIOD',
#        'Tropical Storm Elsa Makes Landfall In Florida Big Bend , With 65 MPH Winds | XL1067',
#        'Tropical Storm Elsa Makes Landfall In Florida Big Bend , With 65 MPH Winds | NewsRadio WFLA',
#        'Tropical Storm Elsa Makes Landfall In Florida Big Bend , With 65 MPH Winds | WMMB - AM',
#        'Live updates : Elsa weakens to a tropical storm ahead of landfall in west Florida',
#        'Elsa : Track the storm path and possible impacts across Florida',
#        'Tropical Storm Elsa expected to become hurricane before making landfall in Florida',
#        'Tropical Storm Elsa Makes Landfall in Florida ; Watches Extended to New Jersey',
#        'Tropical Storm Elsa Approaching Landfall Along Florida West Coast',
#        'Tropical Storm Elsa off the coast of Tampa with 65 mph winds',
#        'Tropical Storm Elsa Weakens Slightly as It Takes Aim at Florida – NBC New York',
#        'Elsa strengthens to hurricane as it approaches Florida coast',
#        'Tropical Storm Elsa to make landfall in Florida',
#        'Elsa weakens to tropical storm as it takes aim at Florida',
#        'Here Comes Elsa : Tropical Storm Will Bring Heavy Rain , Gusty Winds To Region',
#        'Tropical Storm Elsa : Everything you need to know',
#        'Tropical Storm Elsa live updates as storm makes landfall',
#        'Tropical Storm Elsa moves through East Coast , brings flooding threat , strong winds',
#        'Tropical Storm Elsa causes some flash flooding , wind damage in New York , New Jersey and Connecticut',
#        'Tropical Storm Elsa strengthens , expected to dissipate today',
#        'Tropical Storm Elsa to Sweep Through the Northeast with Heavy Rain , Gusty Winds',
#        'Latest Timeline : Tropical Storm Elsa Brings Drenching Rain , Gusty Winds To Northeast',
#        'Tropical Storm Elsa : Millions under tropical storm warnings and flash flood watches as Elsa moves up the East Coast',
#        'Relentless rain : Tropical Storm Elsa sweeps through region',
#        'Tropical Storm Elsa sweeps through region , dumping rain and threatening coastal areas with high winds',
#        'Tropical Storm Elsa unleashes flash flooding , wind damage in New York , New Jersey and Connecticut',
#        'What should we expect from Tropical Storm Elsa in Massachusetts ? Tornado',
#        'TRACKING ELSA : Tropical Storm Elsa brings heavy rain , flooding and possible tornadoes to CT',
#        'Tropical Storm Warning issued for parts of Florida ahead of Elsa',
#        'Tropical Storm Elsa is tracking closer to Florida',
#        'Tropical storm warnings issued for parts of Florida Gulf Coast as Elsa approaches',
#        'Elsa latest : Florida on notice as tropical storm expected to churn over Cuba before passing near Keys',
#        'Elsa makes landfall in Cuba as Florida braces for tropical storm',
#        'Tropical Storm Elsa Gets Stronger Now South of Cuba En Route to Florida | NewsRadio WIOD',
#        'Tropical Storm Elsa Gets Stronger Now South of Cuba En Route to Florida',
#        'Tropical Storm Elsa Gets Stronger Now South of Cuba En Route to Florida | 100 . 7 WFLA',
#        'Tropical Storm Elsa Gets Stronger Now South of Cuba En Route to Florida | 1290 WJNO',
#        'Tropical Storm Elsa Gets Stronger Now South of Cuba En Route to Florida | WMMB - AM',
#        'Tropical Storm Elsa Gets Stronger Now South of Cuba En Route to Florida | 94 . 5 WFLA',
#        'Tropical Storm Elsa Gets Stronger Now South of Cuba En Route to Florida | NewsRadio WFLA',
#        'Tropical Storm Elsa Gets Stronger Now South of Cuba En Route to Florida | BIG 105 . 9',
#        'Tropical Storm Elsa Gets Stronger Now South of Cuba En Route to Florida | Newsradio WFLA Orlando',
#        'Tropical Storm Elsa Gets Stronger Now South of Cuba En Route to Florida | XL1067',
#        'Tropical Storm Elsa : Tampa Bay now under tropical storm warning',
#        'Tropical Storm Elsa : Track the storm path as it approaches Florida',
#        'Tropical storm conditions expected in portions of Florida after Elsa impacts Cuba',
#        'Tropical Storm Warning Issued For Tampa Area Ahead of Elsa Arrival',
#        'Tropical Storm Elsa heads toward the coast of Cuba with hurricane potential',
#        'Tropical Storm Warning Issued For Tampa Bay As TS Elsa Nears',
#        'Tropical Storm Elsa Update : National Hurricane Center Cautions Tampa Bay About Dangerous Path',
#        'Tropical Storm Elsa Nearing Cuba ; Tropical Storm Watches and Warnings Issued in Florida',
#        'Tropical Storm Elsa makes landfall in Cuba , eyes Florida',
#        'Tropical Storm Elsa nears Cuba . Track nudges west , likely easing impact on Florida Keys',
#        'Tropical Storm Elsa Nears Cuba ; Track Nudges West , Likely Easing Impact on Florida Keys',
#        'Tropical Storm Elsa Nearing Cuba Landfall ; Tropical Storm Watches and Warnings Expanded in Florida',
#        'Tropical Storm Elsa Rainbands Already Spreading Into Florida After Cuba Landfall',
#        'Tropical Storm Elsa Nearing Cuba Landfall ; Tropical Storm Watches and Warnings Issued in Florida',
#        'Tropical Storm Elsa could re - strengthen over open water before impacting NC :: WRAL . com',
#        'Hurricane Elsa tracker : Latest Tropical Storm path and forecast map – and when it set to hit Florida coast',
#        'Tropical Storm Elsa Weakens and Slows as it Eyes Cuba En Route to Florida',
#        'Elsa latest : Tropical storm warning issued for parts of Florida Keys',
#        'Elsa remains a tropical storm , tracking towards Florida early this week . ',
#        'Forecasters keep a watchful eye on Tropical Storm Elsa as it tracks closer to Florida',
#        'Tropical Storm Elsa in the Atlantic : Track the storm and its possible impacts',
#        'Where is Tropical Storm Elsa on Sunday as it heads toward Florida ? The latest path',
#        'Where is Tropical Storm Elsa ? Track the latest path as it heads toward Florida',
#        'Elsa path : Storm weakens and slows , but a tropical storm watch is in effect for South Florida',
#        'Tropical Storm Elsa Soaking Jamaica , Cuba as it Tracks Toward Florida',
#        'Tropical Storm Elsa to re - strengthen , pass through NC :: WRAL . com',
#        'Tropical Storm Elsa Weakens and Slows as it Eyes Cuba En Route to Florida | WMMB - AM',
#        'Tropical Storm Elsa Weakens and Slows as it Eyes Cuba En Route to Florida | 100 . 7 WFLA',
#        'Tropical Storm Elsa Weakens and Slows as it Eyes Cuba En Route to Florida | NewsRadio WFLA',
#        'Tropical Storm Elsa Weakens and Slows as it Eyes Cuba En Route to Florida | 94 . 5 WFLA',
#        'Tropical Storm Elsa Weakens and Slows as it Eyes Cuba En Route to Florida | NewsRadio WIOD',
#        'Tropical Storm Elsa Weakens and Slows as it Eyes Cuba En Route to Florida | XL1067',
#        'Tropical Storm Elsa Weakens and Slows as it Eyes Cuba En Route to Florida | 1290 WJNO',
#        'Tropical Storm Elsa Weakens and Slows as it Eyes Cuba En Route to Florida | BIG 105 . 9',
#        'Tropical Storm Elsa Weakens and Slows as it Eyes Cuba En Route to Florida | Newsradio WFLA Orlando',
#        'Tropical Storm Elsa nears Cuba amid fears of flooding',
#        'Elsa weakens and slows , but a tropical storm watch is in effect for South Florida',
#        'Tropical Storm Elsa weakens and slows , but a tropical storm watch is in effect for South Florida',
#        'Tropical Storm Elsa Nears Florida As Crews Prepare To Demolish Remains Of Condo',
#        'Tropical Storm Elsa approaches Cuba and eyes Florida',
#        'Tropical Storm Warnings Issued in Florida Keys as Elsa Tracks Through Caribbean',
#        'Tropical Storm Elsa track shift brings it closer to Central Florida as tropical storm watch up for Florida Keys',
#        'Tropical Storm Elsa forecast to bring rain , wind and ocean surge to Florida',
#        'Tropical Storm Elsa Tracking Toward Florida | XL1067',
#        'Tropical Storm Elsa Tracking Toward Florida | 1290 WJNO',
#        'Tropical Storm Elsa Tracking Toward Florida',
#        'Tropical Storm Elsa Tracking Toward Florida | NewsRadio WIOD',
#        'Tropical Storm Elsa Tracking Toward Florida | Newsradio WFLA Orlando',
#        'Tropical Storm Elsa Tracking Toward Florida | NewsRadio WFLA',
#        'Tropical Storm Elsa Tracking Toward Florida | WMMB - AM',
#        'Tropical Storm Elsa Tracking Toward Florida | 100 . 7 WFLA',
#        'Tropical Storm Elsa tracks toward Cuba ; Florida could be next',
#        'Tropical Storm Elsa heads towards Florida - Here the impacts we could see',
#        'Tropical Storm Elsa maintains its strength and speed as cone moves farther away from South Florida',
#        'Tropical Storm Elsa On its Way to the Southeast and Then Maryland',
#        'Elsa will likely be Florida rainmaker , not hurricane',
#        'Tropical Storm Elsa maintains its strength and speed , South Florida remains outside the cone',
#        'Tracking Elsa : back to tropical storm',
#        'Tropical Storm Elsa moves through Caribbean , sets sights on US coastline this week',
#        'Tropical Storm Elsa expected to  minimally impact  Central Florida but prepare anyway',
#        'Tropical Storm Elsa could strengthen some before reaching cuba',
#        'Tropical Storm Elsa heads for Haiti , Cuba , Jamaica and Florida . Storm watch in the Keys',
#        'Tropical Storm Elsa : What To Expect In New Jersey',
#        'Tropical Storm Elsa approaches New York as rain and heavy winds loom',
#        'Tropical Storm Elsa Bringing Heavy Rain , Wind To MA',
#        'Tropical Storm Elsa continues to weaken as storm moves out of Florida',
#        'Tropical Storm Elsa : Mass . Impacts , Hour - by - Hour – NECN',
#        'Elsa latest : Here where the tropical storm is heading next',
#        'Tropical Storm Elsa Nearing Landfall In Florida',
#        'Elsa Soaking the Southeast ; Tropical Storm Warnings Extended Into the Mid - Atlantic',
#        'Tropical Storm Elsa Is Coming To New England – Here What You Can Expect',
#        'TRACKING ELSA : Tropical storm to bring heavy rain , strong winds across Carolinas',
#        'Tropical Storm Elsa could re - strengthen . System brings rain to Texas',
#        'Tropical Storm Elsa impacting the Carolinas on Thursday . Here the latest forecast',
#        'Tropical Storm Elsa : At least 1 dead , multiple injured as storm whips north Florida , pushing toward Georgia and the Carolinas',
#        'Tropical Storm Elsa Makes Landfall Along Florida Gulf Coast – NECN',
#        'Tropical Storm Elsa update : Impact in the Fayetteville area',
#        'TRACKING ELSA : Tropical storm brings heavy rain , strong winds to Carolinas',
#        'Tropical Storm Elsa to make landfall over Florida Wednesday morning ; slight chance of 3rd hurricane formation',
#        'Tropical Storm Elsa : 30 million under tropical storm warnings as Elsa races up the East Coast',
#        'Tropical Storm Elsa brings heavy rain and flooding to Florida , Southeast',
#        'Tropical Storm Elsa : 1 dead , several injured as hurricane moves from Florida into Georgia',
#        'Tropical Storm Elsa is likely to develop this week',
#        'Potential tropical cyclone could become Tropical Storm Elsa',
#        'Atlantic disturbance expected to become Tropical Storm Elsa',
#        'Tropical Storm Elsa likely to form this week in Atlantic',
#        'Tropical Storm Elsa 5 p . m . Update : Elsa moving towards Tampa Bay',
#        'Tropical Storm Elsa producing major rainfall and tropical force winds in Florida',
#        'Tropical Storm Elsa impact on Tallahassee in Florida',
#        'Tropical Storm Elsa impact on Tallahassee in Florida : Track here',
#        'Tropical Storm Elsa moves back over water and forecasted to take aim at Florida next',
#        'Tropical Storm Elsa : Florida braces for potentially life - threatening storm surge',
#        'Tropical Storm Elsa Expected To  Strengthen  Just West Of Key West',
#        'Tropical Storm Elsa Enters the Gulf as Rainbands are Already Spreading Into Florida',
#        'Tropical Storm Elsa Update as Hurricane Watch ,  Life - Threatening  Surge Warnings for Florida',
#        'Hurricane Watch For Tampa Bay Area As Tropical Storm Elsa Meanders Toward Florida',
#        'Elsa latest : Tropical storm heads towards Florida Keys after thrashing Cuba , Caribbean',
#        'Tropical Storm Elsa : What To Expect As Storm Strengthens And Hits Florida',
#        'Tropical Storm Elsa Now Over Florida Straits After Making Landfall in Cuba : NHC',
#        'Tropical Storm Elsa Extected To Strengthen As It Continues To Bring Heavy Rains , Stormy Conditions To Florida Keys , Miami - Dade & Broward',
#        'Elsa May Strengthen Back Into Hurricane As It Barrels Towards Florida | AM 600 WMT',
#        'Elsa May Strengthen Back Into Hurricane As It Barrels Towards Florida | Newstalk 1400 , 104 . 5 , and 105 . 9',
#        'Elsa May Strengthen Back Into Hurricane As It Barrels Towards Florida | Newsradio WOOD 1300 and 106 . 9 FM',
#        'Elsa May Strengthen Back Into Hurricane As It Barrels Towards Florida | WJBO Newsradio 1150 AM & 98 . 7 FM',
#        'Elsa May Strengthen Back Into Hurricane As It Barrels Towards Florida | Talk Radio 105 . 9',
#        'Tropical Storm Elsa impact on Sarasota and Manatee in Florida',
#        'Elsa path : Tropical storm may become hurricane before Florida landfall',
#        'Tropical Storm Elsa Makes Landfall in Cuba and Now Eyes Florida | NewsRadio WIOD',
#        'Tropical Storm Elsa Makes Landfall in Cuba and Now Eyes Florida | 94 . 5 WFLA',
#        'Tropical Storm Elsa Makes Landfall in Cuba and Now Eyes Florida',
#        'Tropical Storm Elsa Makes Landfall in Cuba and Now Eyes Florida | XL1067',
#        'Tropical Storm Elsa Makes Landfall in Cuba and Now Eyes Florida | 100 . 7 WFLA',
#        'Tropical Storm Elsa Makes Landfall in Cuba and Now Eyes Florida | Newsradio WFLA Orlando',
#        'Tropical Storm Elsa Makes Landfall in Cuba and Now Eyes Florida | WMMB - AM',
#        'Tropical Storm Elsa Makes Landfall in Cuba and Now Eyes Florida | NewsRadio WFLA',
#        'Tropical Storm Elsa Makes Landfall in Cuba and Now Eyes Florida | 1290 WJNO',
#        'Elsa weakens to tropical storm as it moves through Caribbean',
#        'Elsa downgraded to tropical storm , expected to hit Florida within days',
#        'Elsa back to a tropical storm',
#        'Hurricane Elsa downgraded to tropical storm ; Florida in path next week',
#        'Elsa downgraded to tropical storm ; Florida in path early next week',
#        'Tracking The Tropics : Hurricane Elsa Downgraded To Tropical Storm As It Continued To Track Towards Florida',
#        'Tracking The Tropics : Hurricane Elsa Downgraded To Tropical Storm As It Continues To Track Towards Florida',
#        'Hurricane Elsa Strengthens',
#        'Elsa Downgraded To Tropical Storm | Newsradio WFLA Orlando',
#        'Tropical Storm Elsa Nearing Hispaniola , Jamaica , Cuba ; Florida Threat Begins Monday',
#        'Tracking The Tropics : Tropical Storm Elsa Continues To Track Towards Florida',
#        'Hurricane Elsa threatens Florida with heavy rain , wind early next week',
#        'Tracking Elsa : Elsa downgraded to a tropical storm',
#        'Hurricane Elsa : Saturday forecast for storm . Florida in its cone',
#        'Elsa now a tropical storm as it heads for Haiti , Cuba , Jamaica and Florida',
#        'Elsa Downgraded to Tropical Storm While Moving Toward Hispaniola , Florida Remains in Cone of Concern',
#        'Elsa Strengthens Into Season First Hurricane As It Heads Towards Florida',
#        'Tropical storm Elsa : Jacksonville may feel impact of winds , rain early Monday',
#        'Category 1 Hurricane Elsa : Florida remains in the  cone of uncertainty  ',
#        'Hurricane Elsa weakens as storm continues across Caribbean ; Florida remains in projected path',
#        'Tropical Storm Elsa : Saturday forecast for storm . Florida in its cone',
#        'Elsa weakens to a tropical storm',
#        'Weakened Tropical Storm Elsa still has Florida bracing for rain , wind',
#        'Hurricane Elsa , 1st of season , could hit Florida next week',
#        'Elsa strengthens into the season first hurricane , and could pose a threat to Florida by next week',
#        'Tropical Storm Elsa whips Dominican Republic and Haiti , and could threaten Florida next week',
#        'Hurricane Elsa brings strong winds and heavy rain to the Caribbean',
#        'Detailed Summary of Tropical Storm Elsa',
#        'Track Of Tropical Storm Elsa Could Impact Florida West Coast',
#        'Tropical Storm Elsa strengthens as it races toward Caribbean . South Florida remains in its path . ',
#        'Tropical Storm Elsa : Florida in path , strengthening expected',
#        'Tropical Storm Elsa forms east of the Caribbean ; South Florida may be in path this week',
#        'Tropical Storm Elsa path : South Florida may be in path after Caribbean',
#        'Tropical Storm Elsa : Most of Florida in 5 - day cone',
#        'Tropical Storm Elsa Forms',
#        'Tropical Storm Elsa forms in the Atlantic , could hit Florida',
#        'Tropical Storm Elsa forms in Atlantic and is expected to bring heavy rain to Caribbean',
#        'Tropical Storm Elsa 2021 path : South Florida in path after Caribbean',
#        'Tropical Storm Elsa Develops in the Atlantic | 94 . 5 WFLA',
#        'Tropical Storm Elsa Develops in the Atlantic',
#        'Forecasters say tropical storm could become Hurricane Elsa on an uncertain path toward Florida',
#        'Tropical Storm Elsa strengthens a little on way to Caribbean , Gulf of Mexico : See track',
#        'Tropical Storm Elsa could hit South Florida early next week - South Florida Sun - Sentinel',
#        'Tropical Storm Elsa forms east of the Caribbean ; South Florida may be in path next week',
#        'Tropical Storm Elsa Forms Over Atlantic :: WRAL . com',
#        'Tropical Storm Elsa Develops in the Atlantic | XL1067',
#        'Tropical Storm Elsa Develops in the Atlantic | NewsRadio WIOD',
#        'Tropical Storm Elsa forms in Atlantic with Florida peninsula in potential path',
#        'Tropical Storm Elsa forms in the Atlantic',
#        'Why Tropical Storm Elsa is such an unusual system',
#        'Tropical Storm Elsa forms , expected to reach Gulf of Mexico next week : See track',
#        'Tropical Storm Elsa : Will Tropical Storm Elsa impact Florida ? ',
#        'TRACK , MODELS , UPDATES : Tropical Storm Elsa on projected path to Florida',
#        'Tropical Storm Elsa forms in the Atlantic and could near the Florida Peninsula by next week',
#        'Tropical Storm Elsa forms',
#        'Tropical Storm Elsa Forms ; South Florida In Crosshairs Next Week',
#        'Tropical Storm Elsa Forms : Florida , Caribbean Should Track Forecast Closely',
#        'Tropical Storm Elsa Moving Quickly : Florida , Caribbean Should Track Forecast Closely',
#        'Tropical Storm Elsa forms , heading toward Florida Keys',
#        'Tropical Storm Elsa Forms in Atlantic , South Florida Remains in Cone of Concern',
#        'Tropical Storm Elsa already a record - breaker as it eyes Florida',
#        'Tropical Storm Elsa : Potential impacts to Florida',
#        'Tropical Storm Elsa to track through the Carribean , nearing Florida next week',
#        'South Florida remains in cone of uncertainty as Tropical Storm Elsa picks up speed',
#        'Tropical Storm Elsa Continues Through The Atlantic',
#        'Tropical Storm Elsa Continues Through The Atlantic | WMMB - AM',
#        'Tropical Storm Elsa Develops in the Atlantic | BIG 105 . 9',
#        'Tropical Storm Elsa Develops in the Atlantic | Newsradio WFLA Orlando',
#        'Tropical Storm Elsa Develops in the Atlantic | 100 . 7 WFLA',
#        'Tropical Storm Elsa Continues Through The Atlantic | NewsRadio WFLA',
#        'Tropical Storm Elsa forms in the Atlantic , South Florida in forecast cone',
#        'Tropical Storm Elsa Threatens Caribbean , South Florida Remains in Cone of Concern',
#        'Tropical Storm Elsa , 5th named storm of season , forms . Will track bring it to Florida ? ',
#        'Tropical Storm Elsa speeding toward the Caribbean with South Florida in the cone',
#        'Tropical Storm Elsa heads to Florida as fifth named storm',
#        'Tropical Storm Elsa forms , could impact Florida - The Washington Post',
#        'Tropical Storm Elsa forms , Florida within 5 - day path',
#        'Tropical Storm Elsa forms with most of South Florida in cone of uncertainty',
#        'Tropical Storm Elsa is here . What do you need to know ? ',
#        'Tropical Storm Elsa strengthens . Most of Florida now in NHC cone of uncertainty . ',
#        'Tropical Storm Elsa moving rapidly towards Caribbean',
#        'Elsa strengthens into Category 1 hurricane . Most of Florida now in NHC cone of uncertainty . ',
#        'Hurricane Elsa : Where and when could Category 1 storm hit Florida ? ',
#        'Tropical Storm Elsa : Track storm path and possible impacts to Palm Beach',
#        'Tropical Storm Elsa : Track storm path and possible impacts to Naples',
#        'Tropical Storm Elsa strengthens with Florida in its path ; NHC updates',
#        'Tropical Storm Elsa : Major Atlantic system has majority of Florida in its cone',
#        '5PM Advisory on Tropical Storm Elsa | Totally 93 . 9 Miami',
#        'Tropical Storm Elsa expected to strengthen as it heads toward Caribbean ; see forecast',
#        'Too early to predict Tropical Storm Elsa impact in Alachua , Marion',
#        'Elsa becomes first hurricane of the year ; Florida in projected cone',
#        'Hurricane Elsa Strengthens | 100 . 7 WFLA',
#        'Hurricane Elsa Strengthens | Totally 93 . 9 Miami',
#        'Florida in Tropical Storm Elsa forecast , and parts of Haiti under hurricane watch',
#        'All of South Florida in Tropical Storm Elsa cone of uncertainty',
#        'Tropical Storm Elsa path : See spaghetti models , storm tracker Florida',
#        'Elsa strengthens into first hurricane of Atlantic season off Florida',
#        'All of Florida in Tropical Storm Elsa Cone of Uncertainty | 1290 WJNO',
#        'All of Florida in Tropical Storm Elsa Cone of Uncertainty',
#        'All of Florida in Tropical Storm Elsa Cone of Uncertainty | 94 . 5 WFLA',
#        'Tracking Tropical Storm Elsa : See spaghetti models , path and storm activity for Florida',
#        'Elsa noon update for North Central Florida : A hurricane now but expected to weaken at landfall',
#        'Hurricane Elsa forms , expected to head into Gulf and then hit Florida : See track',
#        'Tracking Hurricane Elsa : See spaghetti models , path and storm activity for Florida',
#        'Tropical Storm Elsa Path Update as Rapidly Moving Storm Heads Toward Florida',
#        'Tropical Storm Elsa Strengthens To Hurricane',
#        'Tropical Storm Elsa Strengthens To Hurricane | 100 . 7 WFLA',
#        'Tropical Storm Elsa Strengthens To Hurricane | WMMB - AM',
#        'Tropical Storm Elsa Strengthens To Hurricane | NewsRadio WFLA',
#        'Tropical Storm Elsa Strengthening : Florida , Caribbean Should Track Forecast Closely',
#        'Elsa Strengthens Into Season First Hurricane As It Heads Towards Florida | Newstalk 1400 , 104 . 5 , and 105 . 9',
#        'Elsa Strengthens Into Season First Hurricane As It Heads Towards Florida | Newsradio WOOD 1300 and 106 . 9 FM',
#        'Elsa Strengthens Into Season First Hurricane As It Heads Towards Florida | AM 600 WMT',
#        'Elsa strengthens to hurricane as it approaches Florida',
#        'Elsa intensifies to hurricane as it lashes Florida',
#        'Tropical Storm Elsa makes landfall along Florida Gulf Coast - World News',
#        'Tropical Storm Elsa Nears Florida\xa0With Heavy Rain , Strong Winds',
#        'Tropical Storm Elsa to become hurricane before reaching Florida Gulf Coast',
#        'Tropical Storm Elsa moving across west Cuba , then to Florida',
#        'Tropical Storm Elsa moving across west Cuba , then to Florida | iNFOnews | Thompson - Okanagan News Source',
#        'Cuba , Florida cast wary eye on tropical storm Elsa',
#        'Tropical Storm Elsa pounds East Coast after killing 1 in Florida',
#        'The latest on Tropical Storm Elsa',
#        'Tropical Storm Elsa gaining strength , lashing Florida Keys',
#        'Tampa vulnerable as Tropical Storm Elsa gains strength near Gulf coast',
#        'Tropical Storm Elsa crosses west Cuba and heads for Florida',
#        'Tropical Storm Elsa Set to Strengthen as It Nears Florida Coast',
#        'Tropical Storm Elsa picks up strength as it aims for Florida Gulf Coast',
#        'Tropical Storm Elsa , back over water , takes aim at Florida',
#        'Tropical Storm Elsa gaining strength , lashing Florida Keys | iNFOnews | Thompson - Okanagan News Source',
#        'Elsa strengthens into hurricane ; could near the Florida Peninsula by next week',
#        'Elsa strengthens into a hurricane , the season first , and could near the Florida Peninsula by next week',
#        'Tropical Storm Elsa weakens as it passes over northern Florida',
#        'Elsa strengthens to hurricane as it closes in on Florida',
#        'Tropical Storm Elsa Will Likely Strike Florida as a Hur ... ',
#        'Elsa to Hit Florida as Tropical Storm',
#        'Tropical storm warning still in effect as Elsa stays close to north - east coast',
#        'Tropical Storm Elsa weakens after making landfall in Florida',
#        'Tropical Storm Elsa Churns Toward Florida West Coast',
#        'Tropical Storm Elsa forms in Atlantic',
#        'Tropical Storm Elsa strengthens slightly on approach to Caribbean',
#        'Tropical storm Elsa threatens Caribbean'], dtype=object)

# %%
import requests
message = "Elsa Weakens to a Tropical Storm as It Takes Aim at Florida"
url = 'https://event-extraction.skynet.coypu.org'
json_obj = {'message': message, "key": "32T82GWPSGDJTKFN"}

x = requests.post(url, json = json_obj)
x.text
# Out:
# '{"event arguments":[{"description":" Tropical Storm Allison was a tropical cyclone that produced severe flooding in the southern United States. The second tropical cyclone and the first named storm of the 1989 Atlantic hurricane season, Allison formed on June 24 in the northwestern Gulf of Mexico. Development of Allison was a result of the interaction of a tropical wave and the remnants of Pacific hurricane Hurricane Cosme. It moved south and became a tropical storm on June 26. By June 27, Allison made landfall near Freeport, Texas. Allison quickly weakened to a tropical depression later that day, and transitioned into an extratropical cyclone on the following day.  The storm caused heavy rainfall, amounting to in some places. In total, 11 fatalities resulted from the storm, as well as $560\\u00a0million (1989\\u00a0USD, $ \\u00a0USD) in damage. ","entity":"elsa weakens","id":"Q3301480","label":"PER"},{"description":" A tropical cyclone is a rapidly rotating storm system characterized by a low-pressure center, a closed low-level atmospheric circulation, strong winds, and a spiral arrangement of thunderstorms that produce heavy rain. Depending on its location and strength, a tropical cyclone is referred to by different names, including hurricane (), typhoon (), tropical storm, cyclonic storm, tropical depression, and simply cyclone. A hurricane is a tropical cyclone that occurs in the Atlantic Ocean and northeastern Pacific Ocean, and a typhoon occurs in the northwestern Pacific Ocean; in the south Pacific or Indian Ocean, comparable storms are referred to simply as \\"tropical cyclones\\" or \\"severe cyclonic storms\\".  \\"Tropical\\" refers to the geographical origin of these systems, which form almost exclusively over tropical seas. \\"Cyclone\\" refers to their winds moving in a circle, whirling round their central clear eye, with their winds blowing counterclockwise in the Northern Hemisphere and clockwise in the Southern Hemisphere. The opposite direction of circulation is due to the Coriolis effect. Tropical cyclones typically form over large bodies of relatively warm water. They derive their energy through the evaporation of water from the ocean surface, which ultimately recondenses into clouds and rain when moist air rises and cools to saturation. This energy source differs from that of mid-latitude cyclonic storms, such as nor\'easters and European windstorms, which are fueled primarily by horizontal temperature contrasts. Tropical cyclones are typically between in diameter.  The strong rotating winds of a tropical cyclone are a result of the conservation of angular momentum imparted by the Earth\'s","entity":"tropical storm as it takes aim","id":"Q8092","label":"MISC"},{"description":" Florida () is the southernmost contiguous state in the United States. The state is bordered to the west by the Gulf of Mexico, to the northwest by Alabama, to the north by Georgia, to the east by the Atlantic Ocean, and to the south by the Straits of Florida. Florida is the 22nd-most extensive (), the 3rd-most populous (21,312,211 inhabitants), and the 8th-most densely populated () of the U.S. states. Jacksonville is the most populous municipality in the state and the largest city by area in the contiguous United States. The Miami metropolitan area is Florida\'s most populous urban area. Tallahassee is the state\'s capital.  Florida\'s $1.0\\u00a0trillion economy is the fourth largest in the United States. If it were a country, Florida would be the 16th largest economy in the world, and the 58th most populous . In 2017, Florida\'s per capita personal income was $47,684, ranking 26th in the nation. The unemployment rate in September 2018 was 3.5% and ranked as the 18th in the United States. Florida exports nearly $55\\u00a0billion in goods made in the state, the 8th highest among all states. The Miami Metropolitan Area is by far the largest urban economy in Florida and the 12th largest in the United States with a GDP of $345\\u00a0bi ...

# %%
import requests
message = "Elsa Weakens to a Tropical Storm as It Takes Aim at Florida"
url = 'https://event-extraction.skynet.coypu.org'
json_obj = {'message': message, "key": "32T82GWPSGDJTKFN"}

x = requests.post(url, json = json_obj)
x.text
# Out:
# '{"event arguments":[{"description":" Tropical Storm Allison was a tropical cyclone that produced severe flooding in the southern United States. The second tropical cyclone and the first named storm of the 1989 Atlantic hurricane season, Allison formed on June 24 in the northwestern Gulf of Mexico. Development of Allison was a result of the interaction of a tropical wave and the remnants of Pacific hurricane Hurricane Cosme. It moved south and became a tropical storm on June 26. By June 27, Allison made landfall near Freeport, Texas. Allison quickly weakened to a tropical depression later that day, and transitioned into an extratropical cyclone on the following day.  The storm caused heavy rainfall, amounting to in some places. In total, 11 fatalities resulted from the storm, as well as $560\\u00a0million (1989\\u00a0USD, $ \\u00a0USD) in damage. ","entity":"elsa weakens","id":"Q3301480","label":"PER"},{"description":" A tropical cyclone is a rapidly rotating storm system characterized by a low-pressure center, a closed low-level atmospheric circulation, strong winds, and a spiral arrangement of thunderstorms that produce heavy rain. Depending on its location and strength, a tropical cyclone is referred to by different names, including hurricane (), typhoon (), tropical storm, cyclonic storm, tropical depression, and simply cyclone. A hurricane is a tropical cyclone that occurs in the Atlantic Ocean and northeastern Pacific Ocean, and a typhoon occurs in the northwestern Pacific Ocean; in the south Pacific or Indian Ocean, comparable storms are referred to simply as \\"tropical cyclones\\" or \\"severe cyclonic storms\\".  \\"Tropical\\" refers to the geographical origin of these systems, which form almost exclusively over tropical seas. \\"Cyclone\\" refers to their winds moving in a circle, whirling round their central clear eye, with their winds blowing counterclockwise in the Northern Hemisphere and clockwise in the Southern Hemisphere. The opposite direction of circulation is due to the Coriolis effect. Tropical cyclones typically form over large bodies of relatively warm water. They derive their energy through the evaporation of water from the ocean surface, which ultimately recondenses into clouds and rain when moist air rises and cools to saturation. This energy source differs from that of mid-latitude cyclonic storms, such as nor\'easters and European windstorms, which are fueled primarily by horizontal temperature contrasts. Tropical cyclones are typically between in diameter.  The strong rotating winds of a tropical cyclone are a result of the conservation of angular momentum imparted by the Earth\'s","entity":"tropical storm as it takes aim","id":"Q8092","label":"MISC"},{"description":" Florida () is the southernmost contiguous state in the United States. The state is bordered to the west by the Gulf of Mexico, to the northwest by Alabama, to the north by Georgia, to the east by the Atlantic Ocean, and to the south by the Straits of Florida. Florida is the 22nd-most extensive (), the 3rd-most populous (21,312,211 inhabitants), and the 8th-most densely populated () of the U.S. states. Jacksonville is the most populous municipality in the state and the largest city by area in the contiguous United States. The Miami metropolitan area is Florida\'s most populous urban area. Tallahassee is the state\'s capital.  Florida\'s $1.0\\u00a0trillion economy is the fourth largest in the United States. If it were a country, Florida would be the 16th largest economy in the world, and the 58th most populous . In 2017, Florida\'s per capita personal income was $47,684, ranking 26th in the nation. The unemployment rate in September 2018 was 3.5% and ranked as the 18th in the United States. Florida exports nearly $55\\u00a0billion in goods made in the state, the 8th highest among all states. The Miami Metropolitan Area is by far the largest urban economy in Florida and the 12th largest in the United States with a GDP of $345\\u00a0bi ...

# %%
def run_coypu_ee(message):
    url = 'https://event-extraction.skynet.coypu.org'
    json_obj = {'message': message, "key": "32T82GWPSGDJTKFN"}
    x = requests.post(url, json = json_obj)
    try: 
        prediction = x.json()
    except JSONDecodeError:
        prediction = {}
    return prediction.get("event type", None), [e["entity"] for e in prediction.get("event arguments", [{"entity": None}])] 

def run_vicuna_ee(message):
    m = [{"role": "user", "content": f"You are an event extractor which extract event information, which includes event type (storm, hurricane, tornado, flood, tsunami, explosion, wildfire, earthquake, pandemic, drought, shooting, inflation or out-of-scope when the abovementioned classes do not describe the following text), location mentions, causes of events if it is mentioned in the text (e.g., high temporature), consequences of events if it is mentioned in the text(e.g., number of death/injured). Here is the text: {message}. \n Please fill out the information below. \n Event type: \n Location mentions: \n Causes: \n Consequences:  "}]
    url = 'https://turbo.skynet.coypu.org/'
    json_obj = {'messages': message, "key": "M7ZQL9ELMSDXXE86", "temperature": 0.1}
    x = requests.post(url, json = json_obj)
    try: 
        prediction = x.json()
    except JSONDecodeError:
        prediction = {}
    return prediction

# %%
unique_messages = df.loc[df['cluster_25_75'] == 2].title.unique()
event_types = []
entities = []
for title in unique_messages:
    prediction = run_coypu_ee(title)
    event_types.append(prediction[0])
    entities.append(prediction[1])
    print(title)
    print(f"Event type: {prediction[0]}")    
    print(f"Entities: {prediction[1]}")
    print("")
# Out:
# Elsa Weakens to a Tropical Storm as It Takes Aim at Florida
# Event type: tropical_storm
# Entities: ['elsa weakens', 'tropical storm as it takes aim', 'florida']
#
# Storm Elsa Moving on Florida after Battering Cuba
# Event type: tropical_storm
# Entities: ['elsa moving', 'florida', 'battering cuba']
#
# Tropical Storm Elsa Could Hit Tampa Bay Region
# Event type: tropical_storm
# Entities: ['tropical storm elsa could hit', 'tampa bay region']
#
# Tropical Storm Elsa In Cuba , Eyes Florida Next
# Event type: tropical_storm
# Entities: ['cuba', 'eyes florida']
#
# Tropical Storm Elsa May Hit Florida With  Life - Threatening  Storm Surge and Tornadoes
# Event type: tropical_storm
# Entities: ['tropical storm elsa may hit florida with  life - threatening  storm surge']
#
# Storm Elsa regain hurricane strength as it batters Florida with heavy rains , winds and power outages
# Event type: tropical_storm
# Entities: ['elsa', 'florida']
#
# Tropical Storm Elsa hits Florida but weakened winds limit damage
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'florida']
#
# Elsa strengthens into a hurricane as it heads to Gulf Coast
# Event type: tropical_storm
# Entities: ['elsa', 'gulf coast']
#
# Elsa weakens to tropical storm as it threatens Florida coast
# Event type: tropical_storm
# Entities: ['elsa', 'florida']
#
# Elsa strengthens into hurricane as it heads to Gulf Coast
# Event type: tropical_storm
# Entities: ['elsa', 'gulf coast']
#
# Storm Elsa path tracker LIVE - Tropical storm to hit Florida coast ANY TIME as hurricane & tornado threat declared
# Event type: tropical_storm
# Entities: ['florida']
#
# Tropical Storm Elsa poised to make landfall in Florida
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'florida']
#
# Weakening Elsa makes landfall but Florida spared significant damage
# Event type: tropical_storm
# Entities: ['elsa', 'florida']
#
# Storm Elsa regains strength and becomes a HURRICANE
# Event type: tropical_storm
# Entities: ['elsa']
#
# Tropical Storm Elsa makes landfall and batters Florida with 70mph winds as rescuers hunt for 9 missing in water
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'florida']
#
# Tropical Storm Elsa : Cuba reels as storm moves towards Florida
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'cuba', 'florida']
#
# Tropical Storm Elsa takes aim at Florida after passing Cuba
# Event type: tropical_storm
# Entities: ['storm elsa', 'florida', 'cuba']
#
# Tropical Storm Elsa gaining strength as it lashes Florida Keys
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'florida keys']
#
# Tropical Storm Elsa approaches Florida after 180 , 000 evacuated in Cuba
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'florida', 'cuba']
#
# Tropical Storm Elsa lashes Florida Keys as conditions worsen
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'florida keys']
#
# Hurricane Elsa : Storm heads towards Haiti and the Dominican Republic on possible path to Cuba and Florida
# Event type: tropical_storm
# Entities: ['elsa', 'haiti', 'dominican republic', 'cuba', 'florida']
#
# Hurricane Elsa path tracker : Where will storm hit and will it reach Florida ?
# Event type: tropical_storm
# Entities: ['elsa', 'florida']
#
# Storm Elsa has become a hurricane , the first of the season , and is barreling towards Florida
# Event type: tropical_storm
# Entities: ['elsa', 'florida']
#
# Storm Elsa : How is it evolving and how far is it from Florida ?
# Event type: tropical_storm
# Entities: ['florida']
#
# Tropical storm Elsa batters Cuban and Florida coasts - Israel National News
# Event type: tropical_storm
# Entities: ['elsa', 'cuban', 'florida', 'israel national news']
#
# Elsa strengthens to hurricane as it hovers off the coast of Florida
# Event type: tropical_storm
# Entities: ['elsa', 'florida']
#
# Tropical Storm Elsa hits Cuba as it heads towards Florida Keys
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'cuba', 'florida keys']
#
# Elsa weakens to tropical storm , heads towards Florida Gulf coast
# Event type: tropical_storm
# Entities: ['elsa', 'florida gulf']
#
# Tropical storm Elsa makes landfall in Cuba , on track to Florida
# Event type: tropical_storm
# Entities: ['elsa', 'cuba', 'florida']
#
# Tropical Storm Elsa skirts Key West , aims for Florida Gulf Coast
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'key west', 'florida gulf coast']
#
# Storm Elsa moves over Florida Straits after battering Cuba
# Event type: tropical_storm
# Entities: ['elsa', 'florida straits', 'cuba']
#
# Tropical Storm Elsa , Back Over Water , Takes Aim at Florida
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'back over water', 'takes aim', 'florida']
#
# Tropical storm Elsa forms over Atlantic
# Event type: tropical_storm
# Entities: ['elsa', 'atlantic']
#
# Tropical Storm Elsa makes landfall on Florida Gulf Coast
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'florida gulf coast']
#
# Tropical storm Elsa brings heavy rains to Cuba - World News
# Event type: tropical_storm
# Entities: ['elsa', 'cuba', 'world news']
#
# So far , little impact for Florida growers following Hurricane Elsa
# Event type: tropical_storm
# Entities: ['florida', 'elsa']
#
# Tropical Storm Elsa strengthens into hurricane lashing Florida
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'florida']
#
# US : Tropical storm Elsa rages through East Coast | News | DW
# Event type: tropical_storm
# Entities: ['us', 'elsa', 'east coast']
#
# Storm Elsa Moving On Florida After Battering Cuba
# Event type: tropical_storm
# Entities: ['florida', 'cuba']
#
# Tropical Storm Elsa Weakens After Making Landfall In Florida
# Event type: tropical_storm
# Entities: ['florida']
#
# Tropical Storm Elsa wreaks havoc as it tears through the Caribbean
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'caribbean']
#
# Storm Elsa strengthens into a hurricane as it hurtles towards Florida Gulf Coast
# Event type: tropical_storm
# Entities: ['storm elsa', 'florida gulf coast']
#
# Elsa strengthens to hurricane and takes aims at Florida
# Event type: tropical_storm
# Entities: ['elsa', 'florida']
#
# USA News Headlines Today Live Updates : Tropical storm Elsa weakens , spares Florida of major damage
# Event type: tropical_storm
# Entities: ['usa news', 'elsa', 'florida']
#
# Tropical Storm Elsa becomes hurricane , expected to make landfall on Florida Gulf Coast
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'florida gulf coast']
#
# Elsa Strengthens To Hurricane , Takes Aims At Florida
# Event type: tropical_storm
# Entities: ['elsa strengthens to hurricane', 'florida']
#
# Emergency declared for South Florida as tropical storm Elsa approaches
# Event type: tropical_storm
# Entities: ['south florida', 'elsa']
#
# Emergency in S Florida as storm Elsa approaches
# Event type: tropical_storm
# Entities: ['s florida', 'elsa']
#
# Hurricane Elsa Path : Tropical storm Elsa gaining strength , lashing Florida Keys | World News
# Event type: tropical_storm
# Entities: ['elsa', 'elsa', 'florida keys', 'world news']
#
# Tropical Storm Elsa gaining strength , could become hurricane
# Event type: tropical_storm
# Entities: ['tropical storm elsa']
#
# Tropical storm Elsa set to exit Cuba , take aim at Florida
# Event type: tropical_storm
# Entities: ['elsa', 'cuba', 'florida']
#
# USA News Headlines Today Live Updates : Tropical storm Elsa gaining strength , lashing Florida Keys
# Event type: tropical_storm
# Entities: ['usa news', 'elsa', 'florida keys']
#
# Hurricane Elsa : Elsa strengthens into season first hurricane in Caribbean | World News
# Event type: tropical_storm
# Entities: ['elsa', 'elsa', 'caribbean', 'world news']
#
# Emergency Declared For South Florida as Tropical Storm Elsa Approaches
# Event type: tropical_storm
# Entities: ['south florida', 'tropical storm elsa approaches']
#
# Elsa Nears Hurricane Strength Once Again as Storm Intensifies Ahead of Florida Landfall
# Event type: tropical_storm
# Entities: ['elsa', 'florida landfall']
#
# Tropical Storm Elsa a Stark Reminder to Be Prepared for the Atlantic Hurricane Season
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'atlantic hurricane season']
#
# Tropical Storm Elsa makes landfall Wednesday morning along Florida northern Gulf Coast
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'florida', 'gulf coast']
#
# Tropical Storm Elsa making landfall in Florida
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'florida']
#
# Tropical Storm Elsa nearing landfall along Florida Gulf coast : See track
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'florida gulf']
#
# Tropical Storm Elsa nears landfall along Florida west coast
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'florida']
#
# Tropical Storm Elsa : Here What NYC Can Expect
# Event type: tropical_storm
# Entities: ['tropical storm elsa']
#
# Tropical Storm Elsa moves along Florida west coast , bringing flood , storm surge threat
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'florida']
#
# Elsa storm to make Florida Gulf Coast landfall amid tropical warnings
# Event type: tropical_storm
# Entities: ['elsa', 'florida gulf coast']
#
# FIRST ALERT : SC coast under tropical storm warning ahead of Elsa
# Event type: tropical_storm
# Entities: ['sc', 'elsa']
#
# Tropical Storm Elsa threatens NC , SC coasts with winds and rain . Here the forecast
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'nc', 'sc']
#
# Tropical Storm Warning in effect for SC as Elsa weakens over Florida
# Event type: tropical_storm
# Entities: ['sc', 'elsa', 'florida']
#
# Tropical Storm Warning in effect for SC as Elsa heads to Georgia
# Event type: tropical_storm
# Entities: ['sc', 'elsa', 'georgia']
#
# Tropical Storm Elsa Makes Landfall in Florida
# Event type: tropical_storm
# Entities: ['elsa makes landfall', 'florida']
#
# Tropical Storm Elsa : Storm Makes Landfall In Florida , Tropical Storm Watch Extended Up Coast To New Jersey
# Event type: tropical_storm
# Entities: ['florida', 'new jersey']
#
# Tropical Storm Elsa weakens , spares Florida of major damage
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'florida']
#
# Tropical Storm Elsa nears landfall in Florida , eyes East Coast with heavy rain , wind
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'florida', 'east coast']
#
# Tropical Storm Elsa is moving along Florida coast . When and where will it make landfall ?
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'florida']
#
# Tropical Storm Elsa Makes Landfall In Florida : NPR
# Event type: tropical_storm
# Entities: ['florida', 'npr']
#
# Tropical Storm Elsa makes landfall along Florida Gulf Coast
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'florida gulf coast']
#
# Elsa May Strengthen Back Into Hurricane As It Barrels Towards Florida
# Event type: tropical_storm
# Entities: ['elsa may strengthen back into hurricane as it barrels towards florida']
#
# Elsa May Strengthen Back Into Hurricane As It Barrels Towards Florida | 97 . 3 and 103 . 3 The Bull ICONS
# Event type: tropical_storm
# Entities: ['elsa may strengthen back into hurricane as it barrels towards florida']
#
# Elsa weakening in northern Florida after making landfall Wednesday morning
# Event type: tropical_storm
# Entities: ['elsa', 'florida']
#
# As Elsa nears landfall in Florida , North Carolina officials prepare for system to pass through as tropical storm :: WRAL . com
# Event type: tropical_storm
# Entities: ['elsa', 'florida', 'north carolina']
#
# After strengthening to hurricane status , Elsa is back as a Tropical Storm | 98 . 7 The River
# Event type: tropical_storm
# Entities: ['elsa', 'the river']
#
# Tropical Storm Elsa : Track the storm path and possible impacts
# Event type: tropical_storm
# Entities: ['tropical storm elsa']
#
# Tropical Storm Elsa aims for Florida  Big Bend  :: WRAL . com
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'florida  big bend', 'wral']
#
# Tropical Storm Elsa Approaches Landfall Along Florida West Coast
# Event type: tropical_storm
# Entities: ['florida west coast']
#
# Tropical Storm Elsa Has Made Landfall Along Florida Gulf Coast
# Event type: tropical_storm
# Entities: ['florida gulf coast']
#
# Tropical Storm Elsa churns toward Florida Gulf Coast
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'florida gulf coast']
#
# Tropical Storm Elsa making landfall in Taylor County on Florida Gulf Coast
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'taylor county', 'florida gulf coast']
#
# New forecast : Elsa still close to hurricane strength and is expected to become a hurricane tonight
# Event type: tropical_storm
# Entities: ['elsa']
#
# Tropical Storm Elsa Makes Landfall Along Florida Gulf Coast
# Event type: tropical_storm
# Entities: ['storm elsa makes landfall', 'florida gulf coast']
#
# As Hurricane Elsa nears landfall in Florida , North Carolina officials prepare for system to pass through as tropical storm :: WRAL . com
# Event type: tropical_storm
# Entities: ['elsa', 'florida', 'north carolina']
#
# Elsa near landfall in Florida , tropical storm watch extended west in NC :: WRAL . com
# Event type: tropical_storm
# Entities: ['elsa', 'florida', 'wral']
#
# Elsa weakens to a tropical storm as it takes aim at Florida
# Event type: tropical_storm
# Entities: ['elsa', 'florida']
#
# Tropical Storm Elsa weakens , spares Florida major damage
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'florida']
#
# Stars and Stripes - Tropical Storm Elsa makes landfall along Florida Gulf Coast
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'florida gulf coast']
#
# Elsa strengthens into Category 1 hurricane as it nears Florida :: WRAL . com
# Event type: tropical_storm
# Entities: ['elsa', 'florida', 'wral']
#
# Tropical Storm Elsa weakens , spares Florida of major damage :: WRAL . com
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'florida']
#
# Tropical Storm Elsa Makes Landfall In Florida Big Bend , With 65 MPH Winds
# Event type: tropical_storm
# Entities: ['tropical storm elsa makes landfall in florida big bend']
#
# Tropical Storm Elsa Makes Landfall In Florida Big Bend , With 65 MPH Winds | 94 . 5 WFLA
# Event type: tropical_storm
# Entities: ['tropical storm elsa makes landfall in florida big bend', 'wfla']
#
# Tropical Storm Elsa Makes Landfall In Florida Big Bend , With 65 MPH Winds | NewsRadio WIOD
# Event type: tropical_storm
# Entities: ['tropical storm elsa makes landfall in florida big bend', 'newsradio wiod']
#
# Tropical Storm Elsa Makes Landfall In Florida Big Bend , With 65 MPH Winds | XL1067
# Event type: tropical_storm
# Entities: ['tropical storm elsa makes landfall in florida big bend']
#
# Tropical Storm Elsa Makes Landfall In Florida Big Bend , With 65 MPH Winds | NewsRadio WFLA
# Event type: tropical_storm
# Entities: ['tropical storm elsa makes landfall in florida big bend', 'newsradio wfla']
#
# Tropical Storm Elsa Makes Landfall In Florida Big Bend , With 65 MPH Winds | WMMB - AM
# Event type: tropical_storm
# Entities: ['tropical storm elsa makes landfall in florida big bend']
#
# Live updates : Elsa weakens to a tropical storm ahead of landfall in west Florida
# Event type: tropical_storm
# Entities: ['elsa', 'florida']
#
# Elsa : Track the storm path and possible impacts across Florida
# Event type: tropical_storm
# Entities: ['elsa', 'florida']
#
# Tropical Storm Elsa expected to become hurricane before making landfall in Florida
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'florida']
#
# Tropical Storm Elsa Makes Landfall in Florida ; Watches Extended to New Jersey
# Event type: tropical_storm
# Entities: ['tropical storm elsa makes landfall', 'florida', 'watches extended', 'new jersey']
#
# Tropical Storm Elsa Approaching Landfall Along Florida West Coast
# Event type: tropical_storm
# Entities: ['florida west coast']
#
# Tropical Storm Elsa off the coast of Tampa with 65 mph winds
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'tampa']
#
# Tropical Storm Elsa Weakens Slightly as It Takes Aim at Florida – NBC New York
# Event type: tropical_storm
# Entities: ['tropical storm elsa weakens slightly as it takes aim', 'florida', 'nbc new york']
#
# Elsa strengthens to hurricane as it approaches Florida coast
# Event type: tropical_storm
# Entities: ['elsa', 'florida']
#
# Tropical Storm Elsa to make landfall in Florida
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'florida']
#
# Elsa weakens to tropical storm as it takes aim at Florida
# Event type: tropical_storm
# Entities: ['elsa', 'florida']
#
# Here Comes Elsa : Tropical Storm Will Bring Heavy Rain , Gusty Winds To Region
# Event type: tropical_storm
# Entities: ['here comes elsa : tropical storm will bring heavy rain']
#
# Tropical Storm Elsa : Everything you need to know
# Event type: tropical_storm
# Entities: ['tropical storm elsa']
#
# Tropical Storm Elsa live updates as storm makes landfall
# Event type: tropical_storm
# Entities: ['tropical storm elsa']
#
# Tropical Storm Elsa moves through East Coast , brings flooding threat , strong winds
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'east coast']
#
# Tropical Storm Elsa causes some flash flooding , wind damage in New York , New Jersey and Connecticut
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'new york', 'new jersey', 'connecticut']
#
# Tropical Storm Elsa strengthens , expected to dissipate today
# Event type: tropical_storm
# Entities: ['tropical storm elsa']
#
# Tropical Storm Elsa to Sweep Through the Northeast with Heavy Rain , Gusty Winds
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'northeast', 'heavy rain', 'gusty winds']
#
# Latest Timeline : Tropical Storm Elsa Brings Drenching Rain , Gusty Winds To Northeast
# Event type: tropical_storm
# Entities: ['tropical storm elsa brings drenching rain']
#
# Tropical Storm Elsa : Millions under tropical storm warnings and flash flood watches as Elsa moves up the East Coast
# Event type: tropical_storm
# Entities: ['elsa', 'east coast']
#
# Relentless rain : Tropical Storm Elsa sweeps through region
# Event type: tropical_storm
# Entities: ['tropical storm elsa']
#
# Tropical Storm Elsa sweeps through region , dumping rain and threatening coastal areas with high winds
# Event type: tropical_storm
# Entities: ['tropical storm elsa']
#
# Tropical Storm Elsa unleashes flash flooding , wind damage in New York , New Jersey and Connecticut
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'new york', 'new jersey', 'connecticut']
#
# What should we expect from Tropical Storm Elsa in Massachusetts ? Tornado
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'massachusetts', 'tornado']
#
# TRACKING ELSA : Tropical Storm Elsa brings heavy rain , flooding and possible tornadoes to CT
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'ct']
#
# Tropical Storm Warning issued for parts of Florida ahead of Elsa
# Event type: tropical_storm
# Entities: ['florida', 'elsa']
#
# Tropical Storm Elsa is tracking closer to Florida
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'florida']
#
# Tropical storm warnings issued for parts of Florida Gulf Coast as Elsa approaches
# Event type: tropical_storm
# Entities: ['florida gulf coast', 'elsa']
#
# Elsa latest : Florida on notice as tropical storm expected to churn over Cuba before passing near Keys
# Event type: tropical_storm
# Entities: ['elsa', 'florida', 'cuba', 'keys']
#
# Elsa makes landfall in Cuba as Florida braces for tropical storm
# Event type: tropical_storm
# Entities: ['elsa', 'cuba', 'florida']
#
# Tropical Storm Elsa Gets Stronger Now South of Cuba En Route to Florida | NewsRadio WIOD
# Event type: tropical_storm
# Entities: ['tropical storm elsa gets stronger now south of', 'cuba en route', 'florida', 'newsradio wiod']
#
# Tropical Storm Elsa Gets Stronger Now South of Cuba En Route to Florida
# Event type: tropical_storm
# Entities: ['tropical storm elsa gets stronger now south', 'cuba en route', 'florida']
#
# Tropical Storm Elsa Gets Stronger Now South of Cuba En Route to Florida | 100 . 7 WFLA
# Event type: tropical_storm
# Entities: ['tropical storm elsa gets stronger now south of', 'cuba en route', 'florida', 'wfla']
#
# Tropical Storm Elsa Gets Stronger Now South of Cuba En Route to Florida | 1290 WJNO
# Event type: tropical_storm
# Entities: ['tropical storm elsa gets stronger now south of', 'cuba en route', 'florida', 'wjno']
#
# Tropical Storm Elsa Gets Stronger Now South of Cuba En Route to Florida | WMMB - AM
# Event type: tropical_storm
# Entities: ['tropical storm elsa gets stronger now south of', 'cuba en route', 'florida', 'wmmb']
#
# Tropical Storm Elsa Gets Stronger Now South of Cuba En Route to Florida | 94 . 5 WFLA
# Event type: tropical_storm
# Entities: ['tropical storm elsa gets stronger now south of', 'cuba en route', 'florida', 'wfla']
#
# Tropical Storm Elsa Gets Stronger Now South of Cuba En Route to Florida | NewsRadio WFLA
# Event type: tropical_storm
# Entities: ['tropical storm elsa gets stronger now south of', 'cuba en route', 'florida', 'newsradio wfla']
#
# Tropical Storm Elsa Gets Stronger Now South of Cuba En Route to Florida | BIG 105 . 9
# Event type: tropical_storm
# Entities: ['tropical storm elsa gets stronger now south of', 'cuba en route', 'florida']
#
# Tropical Storm Elsa Gets Stronger Now South of Cuba En Route to Florida | Newsradio WFLA Orlando
# Event type: tropical_storm
# Entities: ['tropical storm elsa gets stronger now south of', 'cuba en route', 'florida', 'newsradio wfla orlando']
#
# Tropical Storm Elsa Gets Stronger Now South of Cuba En Route to Florida | XL1067
# Event type: tropical_storm
# Entities: ['tropical storm elsa gets stronger now south of', 'cuba en route', 'florida']
#
# Tropical Storm Elsa : Tampa Bay now under tropical storm warning
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'tampa bay']
#
# Tropical Storm Elsa : Track the storm path as it approaches Florida
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'florida']
#
# Tropical storm conditions expected in portions of Florida after Elsa impacts Cuba
# Event type: tropical_storm
# Entities: ['florida', 'elsa', 'cuba']
#
# Tropical Storm Warning Issued For Tampa Area Ahead of Elsa Arrival
# Event type: tropical_storm
# Entities: ['tampa area', 'elsa arrival']
#
# Tropical Storm Elsa heads toward the coast of Cuba with hurricane potential
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'cuba']
#
# Tropical Storm Warning Issued For Tampa Bay As TS Elsa Nears
# Event type: tropical_storm
# Entities: ['tampa bay', 'ts elsa']
#
# Tropical Storm Elsa Update : National Hurricane Center Cautions Tampa Bay About Dangerous Path
# Event type: tropical_storm
# Entities: ['national hurricane center', 'tampa bay about dangerous path']
#
# Tropical Storm Elsa Nearing Cuba ; Tropical Storm Watches and Warnings Issued in Florida
# Event type: tropical_storm
# Entities: ['cuba', 'tropical storm watches', 'florida']
#
# Tropical Storm Elsa makes landfall in Cuba , eyes Florida
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'cuba', 'florida']
#
# Tropical Storm Elsa nears Cuba . Track nudges west , likely easing impact on Florida Keys
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'cuba', 'florida keys']
#
# Tropical Storm Elsa Nears Cuba ; Track Nudges West , Likely Easing Impact on Florida Keys
# Event type: tropical_storm
# Entities: ['cuba', 'track nudges west', 'florida keys']
#
# Tropical Storm Elsa Nearing Cuba Landfall ; Tropical Storm Watches and Warnings Expanded in Florida
# Event type: tropical_storm
# Entities: ['cuba landfall', 'tropical storm watches', 'florida']
#
# Tropical Storm Elsa Rainbands Already Spreading Into Florida After Cuba Landfall
# Event type: tropical_storm
# Entities: ['tropical storm elsa rainbands', 'florida', 'cuba landfall']
#
# Tropical Storm Elsa Nearing Cuba Landfall ; Tropical Storm Watches and Warnings Issued in Florida
# Event type: tropical_storm
# Entities: ['cuba landfall', 'tropical storm watches', 'florida']
#
# Tropical Storm Elsa could re - strengthen over open water before impacting NC :: WRAL . com
# Event type: tropical_storm
# Entities: ['tropical storm elsa']
#
# Hurricane Elsa tracker : Latest Tropical Storm path and forecast map – and when it set to hit Florida coast
# Event type: tropical_storm
# Entities: ['elsa', 'florida']
#
# Tropical Storm Elsa Weakens and Slows as it Eyes Cuba En Route to Florida
# Event type: tropical_storm
# Entities: ['tropical storm elsa weakens', 'eyes cuba en route', 'florida']
#
# Elsa latest : Tropical storm warning issued for parts of Florida Keys
# Event type: tropical_storm
# Entities: ['elsa', 'florida keys']
#
# Elsa remains a tropical storm , tracking towards Florida early this week .
# Event type: tropical_storm
# Entities: ['elsa', 'florida']
#
# Forecasters keep a watchful eye on Tropical Storm Elsa as it tracks closer to Florida
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'florida']
#
# Tropical Storm Elsa in the Atlantic : Track the storm and its possible impacts
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'atlantic']
#
# Where is Tropical Storm Elsa on Sunday as it heads toward Florida ? The latest path
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'florida']
#
# Where is Tropical Storm Elsa ? Track the latest path as it heads toward Florida
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'florida']
#
# Elsa path : Storm weakens and slows , but a tropical storm watch is in effect for South Florida
# Event type: tropical_storm
# Entities: ['elsa', 'south florida']
#
# Tropical Storm Elsa Soaking Jamaica , Cuba as it Tracks Toward Florida
# Event type: tropical_storm
# Entities: ['elsa soaking jamaica', 'cuba', 'florida']
#
# Tropical Storm Elsa to re - strengthen , pass through NC :: WRAL . com
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'wral']
#
# Tropical Storm Elsa Weakens and Slows as it Eyes Cuba En Route to Florida | WMMB - AM
# Event type: tropical_storm
# Entities: ['tropical storm elsa weakens', 'eyes cuba en route', 'florida', 'wmmb']
#
# Tropical Storm Elsa Weakens and Slows as it Eyes Cuba En Route to Florida | 100 . 7 WFLA
# Event type: tropical_storm
# Entities: ['tropical storm elsa weakens', 'eyes cuba en route', 'florida', 'wfla']
#
# Tropical Storm Elsa Weakens and Slows as it Eyes Cuba En Route to Florida | NewsRadio WFLA
# Event type: tropical_storm
# Entities: ['tropical storm elsa weakens', 'eyes cuba en route', 'florida', 'newsradio wfla']
#
# Tropical Storm Elsa Weakens and Slows as it Eyes Cuba En Route to Florida | 94 . 5 WFLA
# Event type: tropical_storm
# Entities: ['tropical storm elsa weakens', 'eyes cuba en route', 'florida', 'wfla']
#
# Tropical Storm Elsa Weakens and Slows as it Eyes Cuba En Route to Florida | NewsRadio WIOD
# Event type: tropical_storm
# Entities: ['tropical storm elsa weakens', 'eyes cuba en route', 'florida', 'newsradio wiod']
#
# Tropical Storm Elsa Weakens and Slows as it Eyes Cuba En Route to Florida | XL1067
# Event type: tropical_storm
# Entities: ['tropical storm elsa weakens', 'eyes cuba en route', 'florida']
#
# Tropical Storm Elsa Weakens and Slows as it Eyes Cuba En Route to Florida | 1290 WJNO
# Event type: tropical_storm
# Entities: ['tropical storm elsa weakens', 'eyes cuba en route', 'florida', 'wjno']
#
# Tropical Storm Elsa Weakens and Slows as it Eyes Cuba En Route to Florida | BIG 105 . 9
# Event type: tropical_storm
# Entities: ['tropical storm elsa weakens', 'eyes cuba en route', 'florida', 'big']
#
# Tropical Storm Elsa Weakens and Slows as it Eyes Cuba En Route to Florida | Newsradio WFLA Orlando
# Event type: tropical_storm
# Entities: ['tropical storm elsa weakens', 'eyes cuba en route', 'florida', 'newsradio wfla orlando']
#
# Tropical Storm Elsa nears Cuba amid fears of flooding
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'cuba']
#
# Elsa weakens and slows , but a tropical storm watch is in effect for South Florida
# Event type: tropical_storm
# Entities: ['elsa', 'south florida']
#
# Tropical Storm Elsa weakens and slows , but a tropical storm watch is in effect for South Florida
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'south florida']
#
# Tropical Storm Elsa Nears Florida As Crews Prepare To Demolish Remains Of Condo
# Event type: tropical_storm
# Entities: ['tropical storm elsa nears florida as crews prepare to demolish remains of condo']
#
# Tropical Storm Elsa approaches Cuba and eyes Florida
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'cuba', 'florida']
#
# Tropical Storm Warnings Issued in Florida Keys as Elsa Tracks Through Caribbean
# Event type: tropical_storm
# Entities: ['florida keys', 'elsa tracks through caribbean']
#
# Tropical Storm Elsa track shift brings it closer to Central Florida as tropical storm watch up for Florida Keys
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'central florida', 'florida keys']
#
# Tropical Storm Elsa forecast to bring rain , wind and ocean surge to Florida
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'florida']
#
# Tropical Storm Elsa Tracking Toward Florida | XL1067
# Event type: tropical_storm
# Entities: ['tropical storm elsa tracking toward', 'florida']
#
# Tropical Storm Elsa Tracking Toward Florida | 1290 WJNO
# Event type: tropical_storm
# Entities: ['florida', 'wjno']
#
# Tropical Storm Elsa Tracking Toward Florida
# Event type: tropical_storm
# Entities: ['storm elsa tracking toward florida']
#
# Tropical Storm Elsa Tracking Toward Florida | NewsRadio WIOD
# Event type: tropical_storm
# Entities: ['florida', 'newsradio wiod']
#
# Tropical Storm Elsa Tracking Toward Florida | Newsradio WFLA Orlando
# Event type: tropical_storm
# Entities: ['florida', 'newsradio wfla orlando']
#
# Tropical Storm Elsa Tracking Toward Florida | NewsRadio WFLA
# Event type: tropical_storm
# Entities: ['florida', 'newsradio wfla']
#
# Tropical Storm Elsa Tracking Toward Florida | WMMB - AM
# Event type: tropical_storm
# Entities: ['florida', 'wmmb']
#
# Tropical Storm Elsa Tracking Toward Florida | 100 . 7 WFLA
# Event type: tropical_storm
# Entities: ['tropical storm elsa tracking toward', 'florida', 'wfla']
#
# Tropical Storm Elsa tracks toward Cuba ; Florida could be next
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'cuba', 'florida']
#
# Tropical Storm Elsa heads towards Florida - Here the impacts we could see
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'florida']
#
# Tropical Storm Elsa maintains its strength and speed as cone moves farther away from South Florida
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'south florida']
#
# Tropical Storm Elsa On its Way to the Southeast and Then Maryland
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'southeast', 'maryland']
#
# Elsa will likely be Florida rainmaker , not hurricane
# Event type: tropical_storm
# Entities: ['elsa', 'florida']
#
# Tropical Storm Elsa maintains its strength and speed , South Florida remains outside the cone
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'south florida']
#
# Tracking Elsa : back to tropical storm
# Event type: tropical_storm
# Entities: ['elsa']
#
# Tropical Storm Elsa moves through Caribbean , sets sights on US coastline this week
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'caribbean', 'us']
#
# Tropical Storm Elsa expected to  minimally impact  Central Florida but prepare anyway
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'central florida']
#
# Tropical Storm Elsa could strengthen some before reaching cuba
# Event type: tropical_storm
# Entities: ['tropical storm elsa']
#
# Tropical Storm Elsa heads for Haiti , Cuba , Jamaica and Florida . Storm watch in the Keys
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'haiti', 'cuba', 'jamaica', 'florida', 'keys']
#
# Tropical Storm Elsa : What To Expect In New Jersey
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'new jersey']
#
# Tropical Storm Elsa approaches New York as rain and heavy winds loom
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'new york']
#
# Tropical Storm Elsa Bringing Heavy Rain , Wind To MA
# Event type: tropical_storm
# Entities: ['tropical storm elsa bringing heavy rain']
#
# Tropical Storm Elsa continues to weaken as storm moves out of Florida
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'florida']
#
# Tropical Storm Elsa : Mass . Impacts , Hour - by - Hour – NECN
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'mass']
#
# Elsa latest : Here where the tropical storm is heading next
# Event type: tropical_storm
# Entities: ['elsa']
#
# Tropical Storm Elsa Nearing Landfall In Florida
# Event type: tropical_storm
# Entities: ['florida']
#
# Elsa Soaking the Southeast ; Tropical Storm Warnings Extended Into the Mid - Atlantic
# Event type: tropical_storm
# Entities: ['elsa soaking', 'tropical storm warnings', 'atlantic']
#
# Tropical Storm Elsa Is Coming To New England – Here What You Can Expect
# Event type: tropical_storm
# Entities: ['tropical storm elsa is coming to new england – here what you can expect']
#
# TRACKING ELSA : Tropical storm to bring heavy rain , strong winds across Carolinas
# Event type: tropical_storm
# Entities: ['carolinas']
#
# Tropical Storm Elsa could re - strengthen . System brings rain to Texas
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'texas']
#
# Tropical Storm Elsa impacting the Carolinas on Thursday . Here the latest forecast
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'carolinas']
#
# Tropical Storm Elsa : At least 1 dead , multiple injured as storm whips north Florida , pushing toward Georgia and the Carolinas
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'florida', 'georgia', 'carolinas']
#
# Tropical Storm Elsa Makes Landfall Along Florida Gulf Coast – NECN
# Event type: tropical_storm
# Entities: ['florida gulf coast', 'necn']
#
# Tropical Storm Elsa update : Impact in the Fayetteville area
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'fayetteville']
#
# TRACKING ELSA : Tropical storm brings heavy rain , strong winds to Carolinas
# Event type: tropical_storm
# Entities: ['carolinas']
#
# Tropical Storm Elsa to make landfall over Florida Wednesday morning ; slight chance of 3rd hurricane formation
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'florida']
#
# Tropical Storm Elsa : 30 million under tropical storm warnings as Elsa races up the East Coast
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'elsa', 'east coast']
#
# Tropical Storm Elsa brings heavy rain and flooding to Florida , Southeast
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'florida', 'southeast']
#
# Tropical Storm Elsa : 1 dead , several injured as hurricane moves from Florida into Georgia
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'florida', 'georgia']
#
# Tropical Storm Elsa is likely to develop this week
# Event type: tropical_storm
# Entities: ['tropical storm elsa']
#
# Potential tropical cyclone could become Tropical Storm Elsa
# Event type: tropical_storm
# Entities: ['tropical storm elsa']
#
# Atlantic disturbance expected to become Tropical Storm Elsa
# Event type: tropical_storm
# Entities: ['atlantic', 'tropical storm elsa']
#
# Tropical Storm Elsa likely to form this week in Atlantic
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'atlantic']
#
# Tropical Storm Elsa 5 p . m . Update : Elsa moving towards Tampa Bay
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'elsa', 'tampa bay']
#
# Tropical Storm Elsa producing major rainfall and tropical force winds in Florida
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'florida']
#
# Tropical Storm Elsa impact on Tallahassee in Florida
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'tallahassee', 'florida']
#
# Tropical Storm Elsa impact on Tallahassee in Florida : Track here
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'tallahassee', 'florida']
#
# Tropical Storm Elsa moves back over water and forecasted to take aim at Florida next
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'florida']
#
# Tropical Storm Elsa : Florida braces for potentially life - threatening storm surge
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'florida']
#
# Tropical Storm Elsa Expected To  Strengthen  Just West Of Key West
# Event type: tropical_storm
# Entities: ['tropical storm elsa expected to  strengthen  just west of key west']
#
# Tropical Storm Elsa Enters the Gulf as Rainbands are Already Spreading Into Florida
# Event type: tropical_storm
# Entities: ['gulf', 'florida']
#
# Tropical Storm Elsa Update as Hurricane Watch ,  Life - Threatening  Surge Warnings for Florida
# Event type: tropical_storm
# Entities: ['tropical storm elsa update', 'florida']
#
# Hurricane Watch For Tampa Bay Area As Tropical Storm Elsa Meanders Toward Florida
# Event type: tropical_storm
# Entities: ['tampa bay area', 'tropical storm elsa meanders', 'florida']
#
# Elsa latest : Tropical storm heads towards Florida Keys after thrashing Cuba , Caribbean
# Event type: tropical_storm
# Entities: ['elsa', 'florida keys', 'cuba', 'caribbean']
#
# Tropical Storm Elsa : What To Expect As Storm Strengthens And Hits Florida
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'florida']
#
# Tropical Storm Elsa Now Over Florida Straits After Making Landfall in Cuba : NHC
# Event type: tropical_storm
# Entities: ['tropical storm elsa now over', 'florida straits', 'cuba', 'nhc']
#
# Tropical Storm Elsa Extected To Strengthen As It Continues To Bring Heavy Rains , Stormy Conditions To Florida Keys , Miami - Dade & Broward
# Event type: tropical_storm
# Entities: ['tropical storm elsa extected to strengthen as it continues to bring heavy rains', 'florida keys', 'miami', 'dade & broward']
#
# Elsa May Strengthen Back Into Hurricane As It Barrels Towards Florida | AM 600 WMT
# Event type: tropical_storm
# Entities: ['elsa may strengthen back into hurricane as it barrels towards florida']
#
# Elsa May Strengthen Back Into Hurricane As It Barrels Towards Florida | Newstalk 1400 , 104 . 5 , and 105 . 9
# Event type: tropical_storm
# Entities: ['elsa may strengthen back into hurricane as it barrels towards florida', 'newstalk']
#
# Elsa May Strengthen Back Into Hurricane As It Barrels Towards Florida | Newsradio WOOD 1300 and 106 . 9 FM
# Event type: tropical_storm
# Entities: ['elsa may strengthen back into hurricane as it barrels towards florida']
#
# Elsa May Strengthen Back Into Hurricane As It Barrels Towards Florida | WJBO Newsradio 1150 AM & 98 . 7 FM
# Event type: tropical_storm
# Entities: ['elsa may strengthen back into hurricane as it barrels towards florida', 'wjbo newsradio']
#
# Elsa May Strengthen Back Into Hurricane As It Barrels Towards Florida | Talk Radio 105 . 9
# Event type: tropical_storm
# Entities: ['elsa may strengthen back into hurricane as it barrels towards florida | talk radio 105']
#
# Tropical Storm Elsa impact on Sarasota and Manatee in Florida
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'sarasota', 'manatee', 'florida']
#
# Elsa path : Tropical storm may become hurricane before Florida landfall
# Event type: tropical_storm
# Entities: ['elsa', 'florida']
#
# Tropical Storm Elsa Makes Landfall in Cuba and Now Eyes Florida | NewsRadio WIOD
# Event type: tropical_storm
# Entities: ['tropical storm elsa makes landfall', 'cuba', 'now eyes florida', 'newsradio wiod']
#
# Tropical Storm Elsa Makes Landfall in Cuba and Now Eyes Florida | 94 . 5 WFLA
# Event type: tropical_storm
# Entities: ['tropical storm elsa makes landfall', 'cuba', 'now eyes florida', 'wfla']
#
# Tropical Storm Elsa Makes Landfall in Cuba and Now Eyes Florida
# Event type: tropical_storm
# Entities: ['tropical storm elsa makes landfall', 'cuba', 'now eyes florida']
#
# Tropical Storm Elsa Makes Landfall in Cuba and Now Eyes Florida | XL1067
# Event type: tropical_storm
# Entities: ['tropical storm elsa makes landfall', 'cuba', 'now eyes florida']
#
# Tropical Storm Elsa Makes Landfall in Cuba and Now Eyes Florida | 100 . 7 WFLA
# Event type: tropical_storm
# Entities: ['tropical storm elsa makes landfall', 'cuba', 'now eyes florida', 'wfla']
#
# Tropical Storm Elsa Makes Landfall in Cuba and Now Eyes Florida | Newsradio WFLA Orlando
# Event type: tropical_storm
# Entities: ['tropical storm elsa makes landfall', 'cuba', 'now eyes florida', 'newsradio wfla orlando']
#
# Tropical Storm Elsa Makes Landfall in Cuba and Now Eyes Florida | WMMB - AM
# Event type: tropical_storm
# Entities: ['tropical storm elsa makes landfall', 'cuba', 'now eyes florida', 'wmmb']
#
# Tropical Storm Elsa Makes Landfall in Cuba and Now Eyes Florida | NewsRadio WFLA
# Event type: tropical_storm
# Entities: ['tropical storm elsa makes landfall', 'cuba', 'now eyes florida', 'newsradio wfla']
#
# Tropical Storm Elsa Makes Landfall in Cuba and Now Eyes Florida | 1290 WJNO
# Event type: tropical_storm
# Entities: ['tropical storm elsa makes landfall', 'cuba', 'now eyes florida', 'wjno']
#
# Elsa weakens to tropical storm as it moves through Caribbean
# Event type: tropical_storm
# Entities: ['elsa', 'caribbean']
#
# Elsa downgraded to tropical storm , expected to hit Florida within days
# Event type: tropical_storm
# Entities: ['elsa', 'florida']
#
# Elsa back to a tropical storm
# Event type: tropical_storm
# Entities: ['elsa']
#
# Hurricane Elsa downgraded to tropical storm ; Florida in path next week
# Event type: tropical_storm
# Entities: ['elsa', 'florida']
#
# Elsa downgraded to tropical storm ; Florida in path early next week
# Event type: tropical_storm
# Entities: ['elsa', 'florida']
#
# Tracking The Tropics : Hurricane Elsa Downgraded To Tropical Storm As It Continued To Track Towards Florida
# Event type: tropical_storm
# Entities: ['the tropics : hurricane elsa downgraded to tropical storm as it continued to track towards florida']
#
# Tracking The Tropics : Hurricane Elsa Downgraded To Tropical Storm As It Continues To Track Towards Florida
# Event type: tropical_storm
# Entities: ['the tropics : hurricane elsa downgraded to tropical storm as it continues to track towards florida']
#
# Hurricane Elsa Strengthens
# Event type: tropical_storm
# Entities: ['elsa strengthens']
#
# Elsa Downgraded To Tropical Storm | Newsradio WFLA Orlando
# Event type: tropical_storm
# Entities: ['elsa downgraded to tropical storm', 'newsradio wfla orlando']
#
# Tropical Storm Elsa Nearing Hispaniola , Jamaica , Cuba ; Florida Threat Begins Monday
# Event type: tropical_storm
# Entities: ['hispaniola', 'jamaica', 'cuba', 'florida']
#
# Tracking The Tropics : Tropical Storm Elsa Continues To Track Towards Florida
# Event type: tropical_storm
# Entities: ['tropical storm elsa continues to track', 'florida']
#
# Hurricane Elsa threatens Florida with heavy rain , wind early next week
# Event type: tropical_storm
# Entities: ['elsa', 'florida']
#
# Tracking Elsa : Elsa downgraded to a tropical storm
# Event type: tropical_storm
# Entities: ['elsa', 'elsa']
#
# Hurricane Elsa : Saturday forecast for storm . Florida in its cone
# Event type: tropical_storm
# Entities: ['elsa', 'florida']
#
# Elsa now a tropical storm as it heads for Haiti , Cuba , Jamaica and Florida
# Event type: tropical_storm
# Entities: ['elsa', 'haiti', 'cuba', 'jamaica', 'florida']
#
# Elsa Downgraded to Tropical Storm While Moving Toward Hispaniola , Florida Remains in Cone of Concern
# Event type: tropical_storm
# Entities: ['elsa downgraded', 'hispaniola', 'florida']
#
# Elsa Strengthens Into Season First Hurricane As It Heads Towards Florida
# Event type: tropical_storm
# Entities: ['elsa strengthens into season first hurricane as it heads towards florida']
#
# Tropical storm Elsa : Jacksonville may feel impact of winds , rain early Monday
# Event type: tropical_storm
# Entities: ['elsa', 'jacksonville']
#
# Category 1 Hurricane Elsa : Florida remains in the  cone of uncertainty
# Event type: tropical_storm
# Entities: ['hurricane elsa', 'florida']
#
# Hurricane Elsa weakens as storm continues across Caribbean ; Florida remains in projected path
# Event type: tropical_storm
# Entities: ['elsa', 'caribbean', 'florida']
#
# Tropical Storm Elsa : Saturday forecast for storm . Florida in its cone
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'florida']
#
# Elsa weakens to a tropical storm
# Event type: tropical_storm
# Entities: ['elsa']
#
# Weakened Tropical Storm Elsa still has Florida bracing for rain , wind
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'florida']
#
# Hurricane Elsa , 1st of season , could hit Florida next week
# Event type: tropical_storm
# Entities: ['elsa', 'florida']
#
# Elsa strengthens into the season first hurricane , and could pose a threat to Florida by next week
# Event type: tropical_storm
# Entities: ['elsa', 'florida']
#
# Tropical Storm Elsa whips Dominican Republic and Haiti , and could threaten Florida next week
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'dominican republic', 'haiti', 'florida']
#
# Hurricane Elsa brings strong winds and heavy rain to the Caribbean
# Event type: tropical_storm
# Entities: ['elsa', 'caribbean']
#
# Detailed Summary of Tropical Storm Elsa
# Event type: tropical_storm
# Entities: ['tropical storm elsa']
#
# Track Of Tropical Storm Elsa Could Impact Florida West Coast
# Event type: tropical_storm
# Entities: ['florida west coast']
#
# Tropical Storm Elsa strengthens as it races toward Caribbean . South Florida remains in its path .
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'caribbean', 'south florida']
#
# Tropical Storm Elsa : Florida in path , strengthening expected
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'florida']
#
# Tropical Storm Elsa forms east of the Caribbean ; South Florida may be in path this week
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'caribbean', 'south florida']
#
# Tropical Storm Elsa path : South Florida may be in path after Caribbean
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'south florida', 'caribbean']
#
# Tropical Storm Elsa : Most of Florida in 5 - day cone
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'florida']
#
# Tropical Storm Elsa Forms
# Event type: tropical_storm
# Entities: ['tropical storm elsa forms']
#
# Tropical Storm Elsa forms in the Atlantic , could hit Florida
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'atlantic', 'florida']
#
# Tropical Storm Elsa forms in Atlantic and is expected to bring heavy rain to Caribbean
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'atlantic', 'caribbean']
#
# Tropical Storm Elsa 2021 path : South Florida in path after Caribbean
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'south florida', 'caribbean']
#
# Tropical Storm Elsa Develops in the Atlantic | 94 . 5 WFLA
# Event type: tropical_storm
# Entities: ['tropical storm elsa develops', 'atlantic', 'wfla']
#
# Tropical Storm Elsa Develops in the Atlantic
# Event type: tropical_storm
# Entities: ['tropical storm elsa develops', 'atlantic']
#
# Forecasters say tropical storm could become Hurricane Elsa on an uncertain path toward Florida
# Event type: tropical_storm
# Entities: ['elsa', 'florida']
#
# Tropical Storm Elsa strengthens a little on way to Caribbean , Gulf of Mexico : See track
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'caribbean', 'gulf of mexico']
#
# Tropical Storm Elsa could hit South Florida early next week - South Florida Sun - Sentinel
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'south florida', 'south florida sun', 'sentinel']
#
# Tropical Storm Elsa forms east of the Caribbean ; South Florida may be in path next week
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'caribbean', 'south florida']
#
# Tropical Storm Elsa Forms Over Atlantic :: WRAL . com
# Event type: tropical_storm
# Entities: ['atlantic', 'wral']
#
# Tropical Storm Elsa Develops in the Atlantic | XL1067
# Event type: tropical_storm
# Entities: ['tropical storm elsa develops', 'atlantic']
#
# Tropical Storm Elsa Develops in the Atlantic | NewsRadio WIOD
# Event type: tropical_storm
# Entities: ['tropical storm elsa develops', 'atlantic', 'newsradio wiod']
#
# Tropical Storm Elsa forms in Atlantic with Florida peninsula in potential path
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'atlantic', 'florida']
#
# Tropical Storm Elsa forms in the Atlantic
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'atlantic']
#
# Why Tropical Storm Elsa is such an unusual system
# Event type: tropical_storm
# Entities: ['tropical storm elsa']
#
# Tropical Storm Elsa forms , expected to reach Gulf of Mexico next week : See track
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'gulf of mexico']
#
# Tropical Storm Elsa : Will Tropical Storm Elsa impact Florida ?
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'tropical storm elsa', 'florida']
#
# TRACK , MODELS , UPDATES : Tropical Storm Elsa on projected path to Florida
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'florida']
#
# Tropical Storm Elsa forms in the Atlantic and could near the Florida Peninsula by next week
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'atlantic', 'florida peninsula']
#
# Tropical Storm Elsa forms
# Event type: tropical_storm
# Entities: ['tropical storm elsa']
#
# Tropical Storm Elsa Forms ; South Florida In Crosshairs Next Week
# Event type: tropical_storm
# Entities: ['tropical storm elsa forms', 'south florida']
#
# Tropical Storm Elsa Forms : Florida , Caribbean Should Track Forecast Closely
# Event type: tropical_storm
# Entities: ['tropical storm elsa forms', 'florida', 'caribbean']
#
# Tropical Storm Elsa Moving Quickly : Florida , Caribbean Should Track Forecast Closely
# Event type: tropical_storm
# Entities: ['florida', 'caribbean']
#
# Tropical Storm Elsa forms , heading toward Florida Keys
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'florida keys']
#
# Tropical Storm Elsa Forms in Atlantic , South Florida Remains in Cone of Concern
# Event type: tropical_storm
# Entities: ['storm elsa forms', 'atlantic', 'south florida', 'cone of concern']
#
# Tropical Storm Elsa already a record - breaker as it eyes Florida
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'florida']
#
# Tropical Storm Elsa : Potential impacts to Florida
# Event type: tropical_storm
# Entities: ['florida']
#
# Tropical Storm Elsa to track through the Carribean , nearing Florida next week
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'carribean', 'florida']
#
# South Florida remains in cone of uncertainty as Tropical Storm Elsa picks up speed
# Event type: tropical_storm
# Entities: ['south florida', 'tropical storm elsa']
#
# Tropical Storm Elsa Continues Through The Atlantic
# Event type: tropical_storm
# Entities: ['tropical storm elsa continues through the atlantic']
#
# Tropical Storm Elsa Continues Through The Atlantic | WMMB - AM
# Event type: tropical_storm
# Entities: ['tropical storm elsa continues through the atlantic', 'wmmb']
#
# Tropical Storm Elsa Develops in the Atlantic | BIG 105 . 9
# Event type: tropical_storm
# Entities: ['tropical storm elsa develops', 'atlantic', 'big']
#
# Tropical Storm Elsa Develops in the Atlantic | Newsradio WFLA Orlando
# Event type: tropical_storm
# Entities: ['tropical storm elsa develops', 'atlantic', 'newsradio wfla orlando']
#
# Tropical Storm Elsa Develops in the Atlantic | 100 . 7 WFLA
# Event type: tropical_storm
# Entities: ['tropical storm elsa develops', 'atlantic', 'wfla']
#
# Tropical Storm Elsa Continues Through The Atlantic | NewsRadio WFLA
# Event type: tropical_storm
# Entities: ['tropical storm elsa continues through the atlantic', 'newsradio wfla']
#
# Tropical Storm Elsa forms in the Atlantic , South Florida in forecast cone
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'atlantic', 'south florida']
#
# Tropical Storm Elsa Threatens Caribbean , South Florida Remains in Cone of Concern
# Event type: tropical_storm
# Entities: ['storm elsa threatens caribbean', 'south florida', 'cone of concern']
#
# Tropical Storm Elsa , 5th named storm of season , forms . Will track bring it to Florida ?
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'florida']
#
# Tropical Storm Elsa speeding toward the Caribbean with South Florida in the cone
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'caribbean', 'south florida']
#
# Tropical Storm Elsa heads to Florida as fifth named storm
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'florida']
#
# Tropical Storm Elsa forms , could impact Florida - The Washington Post
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'florida', 'the washington post']
#
# Tropical Storm Elsa forms , Florida within 5 - day path
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'florida']
#
# Tropical Storm Elsa forms with most of South Florida in cone of uncertainty
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'south florida']
#
# Tropical Storm Elsa is here . What do you need to know ?
# Event type: tropical_storm
# Entities: ['tropical storm elsa']
#
# Tropical Storm Elsa strengthens . Most of Florida now in NHC cone of uncertainty .
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'florida', 'nhc']
#
# Tropical Storm Elsa moving rapidly towards Caribbean
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'caribbean']
#
# Elsa strengthens into Category 1 hurricane . Most of Florida now in NHC cone of uncertainty .
# Event type: tropical_storm
# Entities: ['elsa', 'florida', 'nhc']
#
# Hurricane Elsa : Where and when could Category 1 storm hit Florida ?
# Event type: tropical_storm
# Entities: ['elsa', 'florida']
#
# Tropical Storm Elsa : Track storm path and possible impacts to Palm Beach
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'palm beach']
#
# Tropical Storm Elsa : Track storm path and possible impacts to Naples
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'naples']
#
# Tropical Storm Elsa strengthens with Florida in its path ; NHC updates
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'florida', 'nhc']
#
# Tropical Storm Elsa : Major Atlantic system has majority of Florida in its cone
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'major atlantic', 'florida']
#
# 5PM Advisory on Tropical Storm Elsa | Totally 93 . 9 Miami
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'miami']
#
# Tropical Storm Elsa expected to strengthen as it heads toward Caribbean ; see forecast
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'caribbean']
#
# Too early to predict Tropical Storm Elsa impact in Alachua , Marion
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'alachua', 'marion']
#
# Elsa becomes first hurricane of the year ; Florida in projected cone
# Event type: tropical_storm
# Entities: ['elsa', 'florida']
#
# Hurricane Elsa Strengthens | 100 . 7 WFLA
# Event type: tropical_storm
# Entities: ['elsa strengthens', 'wfla']
#
# Hurricane Elsa Strengthens | Totally 93 . 9 Miami
# Event type: tropical_storm
# Entities: ['elsa strengthens', 'miami']
#
# Florida in Tropical Storm Elsa forecast , and parts of Haiti under hurricane watch
# Event type: tropical_storm
# Entities: ['florida', 'tropical storm elsa', 'haiti']
#
# All of South Florida in Tropical Storm Elsa cone of uncertainty
# Event type: tropical_storm
# Entities: ['south florida', 'tropical storm elsa']
#
# Tropical Storm Elsa path : See spaghetti models , storm tracker Florida
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'florida']
#
# Elsa strengthens into first hurricane of Atlantic season off Florida
# Event type: tropical_storm
# Entities: ['elsa', 'atlantic', 'florida']
#
# All of Florida in Tropical Storm Elsa Cone of Uncertainty | 1290 WJNO
# Event type: tropical_storm
# Entities: ['florida', 'tropical storm elsa cone of uncertainty']
#
# All of Florida in Tropical Storm Elsa Cone of Uncertainty
# Event type: tropical_storm
# Entities: ['florida', 'tropical storm elsa cone of uncertainty']
#
# All of Florida in Tropical Storm Elsa Cone of Uncertainty | 94 . 5 WFLA
# Event type: tropical_storm
# Entities: ['florida', 'tropical storm elsa cone of uncertainty', 'wfla']
#
# Tracking Tropical Storm Elsa : See spaghetti models , path and storm activity for Florida
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'florida']
#
# Elsa noon update for North Central Florida : A hurricane now but expected to weaken at landfall
# Event type: tropical_storm
# Entities: ['elsa', 'north central florida']
#
# Hurricane Elsa forms , expected to head into Gulf and then hit Florida : See track
# Event type: tropical_storm
# Entities: ['elsa', 'gulf', 'florida']
#
# Tracking Hurricane Elsa : See spaghetti models , path and storm activity for Florida
# Event type: tropical_storm
# Entities: ['florida']
#
# Tropical Storm Elsa Path Update as Rapidly Moving Storm Heads Toward Florida
# Event type: tropical_storm
# Entities: ['tropical storm elsa path update', 'rapidly moving storm heads toward florida']
#
# Tropical Storm Elsa Strengthens To Hurricane
# Event type: tropical_storm
# Entities: []
#
# Tropical Storm Elsa Strengthens To Hurricane | 100 . 7 WFLA
# Event type: tropical_storm
# Entities: ['wfla']
#
# Tropical Storm Elsa Strengthens To Hurricane | WMMB - AM
# Event type: tropical_storm
# Entities: []
#
# Tropical Storm Elsa Strengthens To Hurricane | NewsRadio WFLA
# Event type: tropical_storm
# Entities: ['newsradio wfla']
#
# Tropical Storm Elsa Strengthening : Florida , Caribbean Should Track Forecast Closely
# Event type: tropical_storm
# Entities: ['tropical storm elsa strengthening', 'florida', 'caribbean']
#
# Elsa Strengthens Into Season First Hurricane As It Heads Towards Florida | Newstalk 1400 , 104 . 5 , and 105 . 9
# Event type: tropical_storm
# Entities: ['elsa strengthens into season first hurricane as it heads towards florida', 'newstalk']
#
# Elsa Strengthens Into Season First Hurricane As It Heads Towards Florida | Newsradio WOOD 1300 and 106 . 9 FM
# Event type: tropical_storm
# Entities: ['elsa strengthens into season first hurricane as it heads towards florida']
#
# Elsa Strengthens Into Season First Hurricane As It Heads Towards Florida | AM 600 WMT
# Event type: tropical_storm
# Entities: ['elsa strengthens into season first hurricane as it heads towards florida']
#
# Elsa strengthens to hurricane as it approaches Florida
# Event type: tropical_storm
# Entities: ['elsa', 'florida']
#
# Elsa intensifies to hurricane as it lashes Florida
# Event type: tropical_storm
# Entities: ['elsa', 'florida']
#
# Tropical Storm Elsa makes landfall along Florida Gulf Coast - World News
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'florida gulf coast', 'world news']
#
# Tropical Storm Elsa Nears Florida With Heavy Rain , Strong Winds
# Event type: tropical_storm
# Entities: ['tropical storm elsa nears florida with heavy rain', 'strong winds']
#
# Tropical Storm Elsa to become hurricane before reaching Florida Gulf Coast
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'florida gulf coast']
#
# Tropical Storm Elsa moving across west Cuba , then to Florida
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'cuba', 'florida']
#
# Tropical Storm Elsa moving across west Cuba , then to Florida | iNFOnews | Thompson - Okanagan News Source
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'cuba', 'florida', 'infonews', 'thompson', 'okanagan news source']
#
# Cuba , Florida cast wary eye on tropical storm Elsa
# Event type: tropical_storm
# Entities: ['cuba', 'florida', 'elsa']
#
# Tropical Storm Elsa pounds East Coast after killing 1 in Florida
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'east coast', 'florida']
#
# The latest on Tropical Storm Elsa
# Event type: tropical_storm
# Entities: ['tropical storm elsa']
#
# Tropical Storm Elsa gaining strength , lashing Florida Keys
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'florida keys']
#
# Tampa vulnerable as Tropical Storm Elsa gains strength near Gulf coast
# Event type: tropical_storm
# Entities: ['tampa', 'tropical storm elsa', 'gulf']
#
# Tropical Storm Elsa crosses west Cuba and heads for Florida
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'cuba', 'florida']
#
# Tropical Storm Elsa Set to Strengthen as It Nears Florida Coast
# Event type: tropical_storm
# Entities: ['strengthen', 'florida coast']
#
# Tropical Storm Elsa picks up strength as it aims for Florida Gulf Coast
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'florida gulf coast']
#
# Tropical Storm Elsa , back over water , takes aim at Florida
# Event type: tropical_storm
# Entities: ['tropical storm elsa', 'florida']
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~/opt/anaconda3/envs/ed/lib/python3.9/site-packages/requests/models.py:971, in Response.json(self, **kwargs)
#     970 try:
# --> 971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File ~/opt/anaconda3/envs/ed/lib/python3.9/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File ~/opt/anaconda3/envs/ed/lib/python3.9/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     333 """Return the Python representation of ``s`` (a ``str`` instance
#     334 containing a JSON document).
#     335
#     336 """
# --> 337 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338 end = _w(s, end).end()
#
# File ~/opt/anaconda3/envs/ed/lib/python3.9/json/decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[71], line 5
#       3 entities = []
#       4 for title in unique_messages:
# ----> 5     prediction = run_coypu_ee(title)
#       6     event_types.append(prediction[0])
#       7     entities.append(prediction[1])
#
# Cell In[70], line 5, in run_coypu_ee(message)
#       3 json_obj = {'message': message, "key": "32T82GWPSGDJTKFN"}
#       4 x = requests.post(url, json = json_obj)
# ----> 5 prediction = x.json() or {}
#       6 return prediction.get("event type", None), [e["entity"] for e in prediction.get("event arguments", [{"entity": None}])]
#
# File ~/opt/anaconda3/envs/ed/lib/python3.9/site-packages/requests/models.py:975, in Response.json(self, **kwargs)
#     971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 975     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
from itertools import chain
list(set(chain(*entities)))
# Out:
# ['tropical storm elsa weakens',
#  'manatee',
#  'dominican republic',
#  'national hurricane center',
#  'tropical storm elsa tracking toward',
#  'texas',
#  'wral',
#  'north carolina',
#  'elsa',
#  'us',
#  'elsa strengthens into season first hurricane as it heads towards florida',
#  'storm elsa',
#  'gusty winds',
#  'cuba en route',
#  'tallahassee',
#  'florida keys',
#  'tropical storm elsa develops',
#  'fayetteville',
#  'cuban',
#  'keys',
#  'storm elsa tracking toward florida',
#  'dade & broward',
#  'new york',
#  'back over water',
#  'tropical storm elsa bringing heavy rain',
#  'newsradio wfla orlando',
#  'florida',
#  'storm elsa forms',
#  'battering cuba',
#  'storm elsa threatens caribbean',
#  'eyes florida',
#  'massachusetts',
#  'elsa makes landfall',
#  'sc',
#  'tropical storm elsa approaches',
#  'palm beach',
#  'elsa arrival',
#  'miami',
#  'thompson',
#  'tropical storm elsa rainbands',
#  'tropical storm elsa gets stronger now south of',
#  'elsa moving',
#  'tropical storm watches',
#  'elsa strengthens to hurricane',
#  'necn',
#  'atlantic',
#  'ct',
#  'south florida sun',
#  'wjno',
#  'okanagan news source',
#  'maryland',
#  'tropical storm as it takes aim',
#  'storm elsa makes landfall',
#  'tropical storm elsa makes landfall in florida big bend',
#  'nbc new york',
#  'israel national news',
#  'newsradio wfla',
#  'nc',
#  'wfla',
#  'tropical storm elsa weakens slightly as it takes aim',
#  'gulf coast',
#  'cuba',
#  's florida',
#  'atlantic hurricane season',
#  'tropical storm elsa cone of uncertainty',
#  'tropical storm elsa',
#  'elsa downgraded',
#  'major atlantic',
#  'wjbo newsradio',
#  'newstalk',
#  'tropical storm elsa meanders',
#  'tropical storm elsa strengthening',
#  'florida straits',
#  'tampa bay',
#  'elsa strengthens',
#  'elsa downgraded to tropical storm',
#  'hurricane elsa',
#  'sentinel',
#  'tampa bay about dangerous path',
#  'the river',
#  'tropical storm elsa extected to strengthen as it continues to bring heavy rains',
#  'carolinas',
#  'the tropics : hurricane elsa downgraded to tropical storm as it continues to track towards florida',
#  'carribean',
#  'strengthen',
#  'tropical storm elsa expected to  strengthen  just west of key west',
#  'caribbean',
#  'usa news',
#  'tropical storm elsa now over',
#  'tropical storm elsa continues through the atlantic',
#  'rapidly moving storm heads toward florida',
#  'hispaniola',
#  'strong winds',
#  'tampa bay area',
#  'ts elsa',
#  'track nudges west',
#  'wmmb',
#  'cone of concern',
#  'tampa bay region',
#  'florida west coast',
#  'tropical storm elsa could hit',
#  'tropical storm elsa update',
#  'georgia',
#  'connecticut',
#  'sarasota',
#  'east coast',
#  'tropical storm elsa path update',
#  'central florida',
#  'cuba landfall',
#  'marion',
#  'tropical storm elsa nears florida with heavy rain',
#  'north central florida',
#  'mass',
#  'elsa may strengthen back into hurricane as it barrels towards florida',
#  'tornado',
#  'the washington post',
#  'naples',
#  'tropical storm elsa nears florida as crews prepare to demolish remains of condo',
#  'world news',
#  'jamaica',
#  'newsradio wiod',
#  'florida landfall',
#  'gulf',
#  'south florida',
#  'here comes elsa : tropical storm will bring heavy rain',
#  'tropical storm elsa continues to track',
#  'takes aim',
#  'gulf of mexico',
#  'southeast',
#  'haiti',
#  'taylor county',
#  'tampa',
#  'heavy rain',
#  'tropical storm elsa is coming to new england – here what you can expect',
#  'florida gulf coast',
#  'elsa soaking',
#  'infonews',
#  'nhc',
#  'eyes cuba en route',
#  'alachua',
#  'big',
#  'florida  big bend',
#  'jacksonville',
#  'tropical storm elsa gets stronger now south',
#  'now eyes florida',
#  'tampa area',
#  'tropical storm elsa forms',
#  'tropical storm elsa makes landfall',
#  'elsa weakens',
#  'tropical storm elsa may hit florida with  life - threatening  storm surge',
#  'npr',
#  'the tropics : hurricane elsa downgraded to tropical storm as it continued to track towards florida',
#  'tropical storm elsa brings drenching rain',
#  'new jersey',
#  'elsa may strengthen back into hurricane as it barrels towards florida | talk radio 105',
#  'elsa soaking jamaica',
#  'tropical storm warnings',
#  'key west',
#  'florida gulf',
#  'northeast',
#  'elsa tracks through caribbean',
#  'florida peninsula',
#  'florida coast',
#  'watches extended']

# %%
# use vicuna to extract number of injures/death, location, event type, causes, consequences

# %%
len(df.loc[df['cluster_25_75'] == 2].title.unique())
# Out:
# 397

# %%
list(set(chain(*event_types)))
# Out:
# ['o', 'l', 'p', 'r', '_', 'a', 'c', 's', 'm', 't', 'i']

# %%
len(event_types)
# Out:
# 384

# %%
filtered_df = df.drop_duplicates(subset=['title'])
filtered_df
# Out:
#         Unnamed: 0                                                url  \
# 0                1  https://www.echoroukonline.com/a-new-stab-by-t...
# 1                3  https://www.echoroukonline.com/algeria-hikes-g...
# 2                2  https://www.echoroukonline.com/sanchez-fails-t...
# 3                3  https://www.echoroukonline.com/colonial-nostal...
# 4                0  https://reliefweb.int/report/antigua-and-barbu...
# ...            ...                                                ...
# 593432           0  https://velveteenrabbi.blogs.com/blog/2022/06/...
# 593433           0  https://clubofmozambique.com/news/watch-the-cy...
# 593434           1  https://clubofmozambique.com/news/watch-severe...
# 593435           0  https://clubofmozambique.com/news/mozambique-t...
# 593436           0  https://clubofmozambique.com/news/mozambique-i...
#
#                                                url_mobile  \
# 0       https://www.echoroukonline.com/a-new-stab-by-t...
# 1       https://www.echoroukonline.com/algeria-hikes-g...
# 2       https://www.echoroukonline.com/sanchez-fails-t...
# 3       https://www.echoroukonline.com/colonial-nostal...
# 4                                                     NaN
# ...                                                   ...
# 593432                                                NaN
# 593433                                                NaN
# 593434                                                NaN
# 593435                                                NaN
# 593436                                                NaN
#
#                                                     title          seendate  \
# 0       A New Stab By The Moroccan Makhzen In Algeria ...  20210718T154500Z
# 1       Algeria Hikes Gas , Oil Supplies To Spain Amid...  20211117T210000Z
# 2       Sanchez Fails to Mobilize NATO Summit Against ...  20220701T223000Z
# 3       Colonial Nostalgia For Algeria Poisons The Fre...  20220629T180000Z
# 4       CCRIF Members in the Caribbean and Central Ame...  20210801T200000Z
# ...                                                   ...               ...
# 593432  Velveteen Rabbi : Land of Promise : Teachings ...  20220625T164500Z
# 593433  Watch :  The cyclone was devastating  – Daviz ...  20210125T170000Z
# 593434  Watch : Severe winds wreck homes , displace th...  20210125T180000Z
# 593435  Mozambique : Total wants 25 km security zone ;...  20210216T163000Z
# 593436  Mozambique : Imminent Tropical Storm – Emergen...  20220122T194500Z
#
#                                               socialimage  \
# 0       https://www.echoroukonline.com/wp-content/uplo...
# 1       https://www.echoroukonline.com/wp-content/uplo...
# 2       https://www.echoroukonline.com/wp-content/uplo...
# 3       https://www.echoroukonline.com/wp-content/uplo...
# 4       https://reliefweb.int/profiles/reliefweb/theme...
# ...                                                   ...
# 593432  https://velveteenrabbi.blogs.com/.a/6a00d8341c...
# 593433  https://clubofmozambique.com/wp-content/upload...
# 593434  https://clubofmozambique.com/wp-content/upload...
# 593435  https://clubofmozambique.com/wp-content/upload...
# 593436  https://clubofmozambique.com/wp-content/upload...
#
#                           domain language sourcecountry  start_date  \
# 0             echoroukonline.com  English       Algeria  2021-07-18
# 1             echoroukonline.com  English       Algeria  2021-11-17
# 2             echoroukonline.com  English       Algeria  2022-07-01
# 3             echoroukonline.com  English       Algeria  2022-06-29
# 4                  reliefweb.int  English         Syria  2021-08-01
# ...                          ...      ...           ...         ...
# 593432  velveteenrabbi.blogs.com  English    Mozambique  2022-06-25
# 593433      clubofmozambique.com  English    Mozambique  2021-01-25
# 593434      clubofmozambique.com  English    Mozambique  2021-01-25
# 593435      clubofmozambique.com  English    Mozambique  2021-02-16
# 593436      clubofmozambique.com  English    Mozambique  2022-01-22
#
#           end_date  cluster_25_75
# 0       2021-07-19            NaN
# 1       2021-11-18            NaN
# 2       2022-07-02            NaN
# 3       2022-06-30            NaN
# 4       2021-08-02            NaN
# ...            ...            ...
# 593432  2022-06-26            NaN
# 593433  2021-01-26            NaN
# 593434  2021-01-26            NaN
# 593435  2021-02-17            NaN
# 593436  2022-01-23          548.0
#
# [373245 rows x 12 columns]

# %%
unique_messages = df.loc[df['cluster_25_75'] == 2].title.unique()
for title in unique_messages:
    prediction = run_vicuna_ee(title)
    print(title)
    print(f"prediction:")    
    print(prediction)
    print("")
# Out:
# Elsa Weakens to a Tropical Storm as It Takes Aim at Florida
# prediction:
# [{'id': 'chatcmpl-yhyTgS7gE9nnkSRJC5yvra', 'object': 'chat.completion', 'created': 1699365009, 'model': 'vicuna-13b-v1.5', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '\nHurricane Elsa weakened to a tropical storm as it took aim at Florida on Wednesday, with forecasters warning of heavy rains and possible flooding as it made its way across the state.\nThe National Hurricane Center said Elsa had maximum sustained winds of 65 miles per hour (105 kph) as it moved over the eastern Gulf of Mexico, and was expected to make landfall in Florida later in the day.\nThe storm was forecast to bring heavy rainfall to much of the state, with some areas potentially seeing up to 10 inches (25 centimeters) of rain.\n“This rainfall may result in flash flooding and rapid rises on small streams and rivers,” the NHC said in an advisory.\nElsa was expected to move across northern Florida into southern Georgia on Wednesday night, before moving into the Carolinas on Thursday.\nThe storm had already caused some damage in the Caribbean, where it made landfall in Barbados as a Category 1 hurricane on Monday, before passing over St. Vincent and the Grenadines and causing flooding in Trinidad and Tobago.\nIn Florida, Governor Ron DeSantis declared a state of emergency and urged residents to prepare for the storm.\n“Now is the time to get ready,” DeSantis said in a statement. “Elsa is a powerful storm, and Floridians should take it seriously.”\nThe state’s emergency management agency urged residents to stock up on supplies, secure their homes and prepare for power outages.\n“We are urging all Floridians to remain vigilant and take the necessary steps to ensure their safety as Tropical Storm Elsa approaches our state,” said the agency’s director, Jared Moskowitz.\nElsa is the earliest fifth-named storm on record in the Atlantic basin, and comes just a month after the official start of the hurricane season on June 1.\nPrevious PostHaiti: At Least 1,419 Dead, 6,952 Injured in 7.2 Magnitude Earthquake\nNext PostHaiti Earthquake: Death Toll Rises to Over 1,400, Search and Rescue Underway'}, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 19, 'total_tokens': 523, 'completion_tokens': 504}}, 200]
#
# Storm Elsa Moving on Florida after Battering Cuba
# prediction:
# [{'id': 'chatcmpl-kgzUxEvTFis5LXxYXsSfSc', 'object': 'chat.completion', 'created': 1699365073, 'model': 'vicuna-13b-v1.5', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '\nHAVANA, Cuba (AP) — Hurricane Elsa weakened slightly as it moved across Cuba on Saturday, but forecasters warned that the storm could regain strength as it approaches Florida, where it could make landfall as soon as Tuesday.\nThe U.S. National Hurricane Center said Elsa’s maximum sustained winds decreased to near 75 mph (120 kph) as it moved across western Cuba, but it was still forecast to be a dangerous storm as it moves into the Gulf of Mexico.\nElsa was centered about 105 miles (170 kilometers) southeast of Key West, Florida, and was moving north-northwest at 14 mph (22 kph).\nA hurricane watch was in effect for the lower Florida Keys, and a tropical storm watch was in effect for the west coast of Florida from the Florida Keys to the Anclote River.\nForecasters said Elsa could bring heavy rainfall, dangerous storm surge and strong winds to parts of Florida, and urged residents to prepare for the possibility of power outages and other potential impacts.\nElsa hit Cuba as a Category 1 hurricane early Saturday, with maximum sustained winds of 80 mph (130 kph). It was the first hurricane to make landfall in Cuba since Hurricane Irma in 2017.\nThe storm caused power outages and flooded homes in some areas, but there were no immediate reports of serious injuries or deaths.\nElsa had earlier caused heavy damage in the Caribbean, where it hit the eastern Caribbean island of Barbados as a Category 1 hurricane before moving on to St. Lucia and Martinique.\nThe storm was expected to bring heavy rainfall to parts of the Dominican Republic, Haiti and Jamaica over the weekend.'}, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 13, 'total_tokens': 442, 'completion_tokens': 429}}, 200]
#
# Tropical Storm Elsa Could Hit Tampa Bay Region
# prediction:
# [{'id': 'chatcmpl-F4im3rqfqpVgA4GUS9CkoZ', 'object': 'chat.completion', 'created': 1699365116, 'model': 'vicuna-13b-v1.5', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': 'As A Strong Tropical Storm\nTropical Storm Elsa is forecast to strengthen into a hurricane as it moves across the Caribbean Sea and into the Gulf of Mexico, and it could bring heavy rain and strong winds to the Tampa Bay region later this week.\nThe National Hurricane Center said Elsa is expected to become a hurricane by Wednesday as it moves over the eastern Caribbean Sea. It\'s currently packing maximum sustained winds of 60 mph, with higher gusts.\nThe storm is forecast to move into the Gulf of Mexico by Thursday and approach the Tampa Bay region by Friday.\nThe Tampa Bay region is under a tropical storm watch, meaning that tropical storm conditions are possible within the next 48 hours.\n"Interests in the northern Caribbean Sea, the Bahamas, and the Florida Peninsula should monitor the progress of Elsa," the National Hurricane Center said in its latest advisory.\nElsa is the earliest fifth-named storm on record in the Atlantic basin, breaking the record set by Edouard in 2020.\nThe 2021 Atlantic hurricane season is already off to an active start, with four named storms forming before the official start of the season on June 1.'}, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 12, 'total_tokens': 303, 'completion_tokens': 291}}, 200]
#
# Tropical Storm Elsa In Cuba , Eyes Florida Next
# prediction:
# [{'id': 'chatcmpl-HBrbXQZcHJSR4frc3sZz2K', 'object': 'chat.completion', 'created': 1699365157, 'model': 'vicuna-13b-v1.5', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '\nTropical Storm Elsa is moving across Cuba and is expected to reach Florida by the weekend. The storm is currently packing maximum sustained winds of 60 mph and is moving northwest at 29 mph.\nThe National Hurricane Center (NHC) has issued a tropical storm warning for the Cuban provinces of Camaguey, Ciego de Avila, Sancti Spiritus, Villa Clara, Matanzas, Cienfuegos, and the city of Havana.\nElsa is expected to bring heavy rainfall and strong winds to Cuba, with the potential for flash flooding and mudslides. The storm is also expected to bring heavy rainfall to Florida, with the potential for flooding and strong winds.\nThe NHC is urging residents in the affected areas to prepare for the possibility of dangerous weather conditions and to follow the advice of local officials.\nElsa is the earliest fifth-named storm on record in the Atlantic basin, and it is the first named storm to impact Cuba since Hurricane Eta last November.\nThe storm is expected to strengthen as it moves across the Gulf of Mexico and approaches the Florida coast. Residents in Florida should monitor the progress of the storm and be prepared to take action if necessary.'}, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 13, 'total_tokens': 289, 'completion_tokens': 276}}, 200]
#
# Tropical Storm Elsa May Hit Florida With  Life - Threatening  Storm Surge and Tornadoes
# prediction:
# [{'id': 'chatcmpl-3VcWGHuyegkjWbVWwqnAKR', 'object': 'chat.completion', 'created': 1699365223, 'model': 'vicuna-13b-v1.5', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '\nTropical Storm Elsa is forecast to hit Florida as a potentially life-threatening storm with storm surge and tornadoes, the National Hurricane Center (NHC) warned on Wednesday.\nThe storm, which formed in the Caribbean Sea, is expected to make landfall in the Florida Panhandle or the Big Bend area on Wednesday evening, the NHC said in its latest advisory.\n“Preparations to protect life and property should be rushed to completion,” the NHC said.\nElsa is currently packing maximum sustained winds of 60 miles per hour (95 km/h) and is moving north-northwest at 13 miles per hour (20 km/h).\nThe NHC warned that Elsa could bring dangerous storm surge, heavy rainfall, and flash flooding to parts of Florida, as well as the possibility of tornadoes.\n“Storm surge warnings and hurricane watches are in effect for portions of the Florida Gulf Coast,” the NHC said.\nThe storm is expected to weaken as it moves inland, but heavy rainfall is still expected across the Southeast over the next few days, the NHC said.\nFlorida Governor Ron DeSantis declared a state of emergency on Wednesday in anticipation of Elsa’s arrival.\n“We urge all Floridians to take this storm seriously and to prepare for the possibility of dangerous storm surge, heavy rainfall, and strong winds,” DeSantis said in a statement.\nElsa is the earliest fifth-named storm on record to form in the Atlantic basin, according to the NHC. The previous record was held by Don in 2003, which formed on July 21.\nThe 2021 Atlantic hurricane season officially began on June 1 and runs through November 30.'}, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 26, 'total_tokens': 451, 'completion_tokens': 425}}, 200]
#
# Storm Elsa regain hurricane strength as it batters Florida with heavy rains , winds and power outages
# prediction:
# [{'id': 'chatcmpl-3tmkTrGZzUv2ECsdnPXjyS', 'object': 'chat.completion', 'created': 1699365257, 'model': 'vicuna-13b-v1.5', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': "\nTropical Storm Elsa has regained hurricane strength as it batters Florida with heavy rains, winds and power outages. The National Hurricane Center said Elsa's maximum sustained winds have increased to near 75 mph (120 kph) with higher gusts. The storm is centered about 10 miles (15 kilometers) south-southwest of Tampa and is moving north-northeast at 15 mph (24 kph).\nThe storm is expected to bring heavy rainfall to parts of Florida, Georgia and South Carolina, with some areas potentially receiving more than a foot of rain.\nElsa made landfall in Taylor County, Florida, on Wednesday as a Category 1 hurricane before weakening to a tropical storm. The storm has already caused power outages and flash flooding in some areas.\nFlorida Governor Ron DeSantis has declared a state of emergency in response to the storm, and officials have urged residents to take precautions and stay safe."}, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 26, 'total_tokens': 257, 'completion_tokens': 231}}, 200]
#
# Tropical Storm Elsa hits Florida but weakened winds limit damage
# prediction:
# [{'id': 'chatcmpl-3V2SQf6YACaLQTwxJzmYtc', 'object': 'chat.completion', 'created': 1699365328, 'model': 'vicuna-13b-v1.5', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '\nTropical Storm Elsa hit Florida\'s Gulf Coast on Wednesday, but the storm\'s winds had weakened significantly by the time it made landfall, sparing the region from the worst-case scenario.\nThe storm\'s center made landfall near Cedar Key, a small island community about 80 miles (130 kilometers) north of Tampa, the National Hurricane Center said.\nElsa had been a Category 1 hurricane earlier in the day, but its winds had dropped to 60 mph (95 kph) by the time it hit Florida.\nThe storm was expected to move across the state and into the Atlantic Ocean by Thursday, the hurricane center said.\nElsa was the earliest fifth-named storm on record in the Atlantic basin, which includes the Caribbean Sea and the Gulf of Mexico. The previous record was held by the 2005 season, which had five named storms by July 6.\nThe storm had already caused some problems in the Caribbean, where it killed at least three people in the Dominican Republic and Haiti and caused flooding and power outages in Puerto Rico.\nIn Florida, Gov. Ron DeSantis declared a state of emergency and urged residents to prepare for the storm.\n"This storm is going to bring heavy rain, strong winds, and dangerous storm surge," DeSantis said. "We want to make sure that people are prepared and that they\'re taking the necessary steps to keep themselves and their families safe."\nThe storm also prompted some evacuations in low-lying areas and beachfront communities, and schools and government offices closed ahead of the storm.\nFlorida\'s Gulf Coast is no stranger to tropical weather, but Elsa was the first named storm to hit the region this year.\nThe last named storm to hit the area was Hurricane Sally, which made landfall near Pensacola in September 2020. That storm caused billions of dollars in damage and was blamed for more than 60 deaths in the U.S. and Caribbean.'}, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 15, 'total_tokens': 487, 'completion_tokens': 472}}, 200]
#
# Elsa strengthens into a hurricane as it heads to Gulf Coast
# prediction:
# [{'id': 'chatcmpl-wH7RH3W49VoCbsUv5u5VLw', 'object': 'chat.completion', 'created': 1699365404, 'model': 'vicuna-13b-v1.5', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '\nMIAMI (AP) — Hurricane Elsa strengthened into a Category 1 storm early Wednesday as it headed toward the northern Gulf Coast, where forecasters warned it could make landfall as a weak hurricane by late Wednesday or early Thursday.\nThe National Hurricane Center said Elsa had maximum sustained winds of 75 mph (120 kph) and was centered about 110 miles (175 kilometers) south-southwest of the mouth of the Mississippi River. It was moving north-northwest at 14 mph (22 kph).\nA hurricane warning was in effect from the Mississippi-Alabama border east to the Suwannee River in Florida, and a storm surge warning was in effect from the Mississippi-Alabama border to the Florida Panhandle.\nForecasters said Elsa could bring 3 to 5 inches (7.5 to 12.5 centimeters) of rain to the northern Gulf Coast, with isolated maximum amounts of 8 inches (20 centimeters) possible. The storm surge could raise water levels by 2 to 4 feet (0.6 to 1.2 meters) above normal tide levels along the coast of Louisiana, Mississippi, Alabama and the Florida Panhandle.\nElsa was expected to bring heavy rain, storm surge and strong winds to the region, and officials warned of the potential for flash flooding and coastal flooding.\nThe storm was expected to make landfall as a weak hurricane, but forecasters warned that Elsa could still bring dangerous conditions to the region.\n“This is a dangerous hurricane, and it’s going to impact the Gulf Coast,” National Hurricane Center Director Ken Graham said during a news conference Tuesday. “We’re looking at a significant storm surge event, and that’s going to be the biggest concern.”\nElsa was the earliest fifth-named storm on record in the Atlantic basin, according to Philip Klotzbach, a hurricane researcher at Colorado State University. The previous record was set by the 2005 season.\nThe storm was expected to bring heavy rain, storm surge and strong winds to the region, and officials warned of the potential for flash'}, 'finish_reason': 'length'}], 'usage': {'prompt_tokens': 17, 'total_tokens': 528, 'completion_tokens': 511}}, 200]
#
# Elsa weakens to tropical storm as it threatens Florida coast
# prediction:
# [{'id': 'chatcmpl-3LvivQ7Uer5XdUAV8EGqv4', 'object': 'chat.completion', 'created': 1699365473, 'model': 'vicuna-13b-v1.5', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '\nMIAMI (AP) — Hurricane Elsa weakened to a tropical storm as it threatened the Florida coast Saturday, with forecasters warning of heavy rains and potential flooding as it churned toward the state’s Gulf Coast.\nThe National Hurricane Center said Elsa’s maximum sustained winds decreased to 70 mph (110 kph) as it moved north-northwest at 16 mph (26 kph). The storm was centered about 105 miles (170 kilometers) southwest of Tampa and was forecast to move across the western Florida Peninsula on Saturday and into the Gulf of Mexico on Sunday.\nA tropical storm warning was in effect for the entire coast of Florida from the Suwannee River to the Ochlockonee River, meaning tropical storm conditions were expected within 36 hours.\nForecasters warned of heavy rainfall across the state, with some areas potentially seeing up to 8 inches (20 centimeters) of rain. The storm surge could raise water levels by 2 to 4 feet (0.6 to 1.2 meters) above normal tide levels along the coast of Florida, the hurricane center said.\n“This rainfall may result in significant river flooding and flash flooding,” the center said in an advisory.\nElsa was the first hurricane of the Atlantic season, which officially began June 1. It made landfall in the Caribbean island of Barbados on July 2 and then swept across the eastern Caribbean, causing flooding and power outages in several islands.\nIn Florida, Gov. Ron DeSantis declared a state of emergency on Friday, urging residents to prepare for the storm. The state’s Division of Emergency Management said in a statement that it was coordinating with utilities and local governments to prepare for potential power outages and other impacts from the storm.\nThe storm was expected to bring heavy rain to parts of Georgia and South Carolina later Saturday and into Sunday, the hurricane center said.'}, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 14, 'total_tokens': 476, 'completion_tokens': 462}}, 200]
#
# Elsa strengthens into hurricane as it heads to Gulf Coast
# prediction:
# [{'id': 'chatcmpl-3vMaJiMbxF6zF3zYy5JrLU', 'object': 'chat.completion', 'created': 1699365537, 'model': 'vicuna-13b-v1.5', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '\nMIAMI (AP) — Hurricane Elsa strengthened into a Category 1 storm early Wednesday as it headed toward the northern Gulf Coast, where forecasters warned it could make landfall as a tropical storm by the end of the week.\nThe National Hurricane Center said Elsa had maximum sustained winds of 75 mph (120 kph) and was centered about 230 miles (370 kilometers) south-southwest of the mouth of the Mississippi River. It was moving north-northwest at 12 mph (19 kph).\nTropical storm warnings were issued for parts of Louisiana, Mississippi and Alabama, and a storm surge warning was in effect for a stretch of the northern Gulf Coast from the Mississippi-Alabama border to the Florida Panhandle.\nForecasters said Elsa could bring heavy rainfall, storm surges and dangerous winds to the region. The storm was expected to approach the northern Gulf Coast on Friday, but it was still too early to predict its exact path and strength.\n“Residents in these areas should ensure they have their hurricane plan in place and listen to advice given by local officials,” the hurricane center said in an advisory.\nElsa was the first hurricane of the Atlantic season, which officially began June 1. It formed in the Caribbean Sea and swept across the eastern Caribbean Islands earlier this week, causing flooding and power outages in some areas.\nThe storm weakened to a tropical storm as it moved over Cuba on Tuesday, but it regained hurricane strength over the warm waters of the Gulf of Mexico.\nForecasters said Elsa could bring heavy rainfall to parts of Florida, Georgia and South Carolina later this week, even if it doesn’t make landfall in the United States.'}, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 16, 'total_tokens': 428, 'completion_tokens': 412}}, 200]
#
# Storm Elsa path tracker LIVE - Tropical storm to hit Florida coast ANY TIME as hurricane & tornado threat declared
# prediction:
# [{'id': 'chatcmpl-3CFdSf7XEwxaZBE75RntJc', 'object': 'chat.completion', 'created': 1699365614, 'model': 'vicuna-13b-v1.5', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '\nTropical Storm Elsa is expected to make landfall in Florida on Wednesday, with the National Hurricane Center (NHC) warning of a "dangerous storm surge, heavy rainfall, and strong winds" as it tracks towards the Sunshine State.\nThe NHC has issued a hurricane watch for a stretch of the Florida coast, from the Suwannee River to the Anclote River, as well as a tornado watch for parts of the state.\nElsa is currently moving north-northwest at 12mph, with maximum sustained winds of 60mph.\nThe storm is expected to bring heavy rainfall to the Florida Keys and the southern and central parts of the state, with some areas potentially seeing up to 10 inches of rain.\nThe NHC has warned of "life-threatening" flash flooding and "significant" river flooding.\nElsa is the earliest fifth-named storm on record to form in the Atlantic basin, beating the previous record set by Don in 2005 by more than a week.\nThe storm is expected to make landfall in Florida on Wednesday, with the National Hurricane Center (NHC) warning of a "dangerous storm surge, heavy rainfall, and strong winds" as it tracks towards the Sunshine State. (Image: NOAA)\nThe NHC said: "Elsa is forecast to move over the southeastern Gulf of Mexico and the west coast of Florida through Wednesday, and then across the eastern Gulf of Mexico on Thursday.\n"Heavy rainfall and gusty winds are expected across portions of the Florida Keys, southern and central Florida, and portions of the southeast United States through Wednesday."\nThe storm is currently around 105 miles south-southeast of Tampa, Florida, and is moving north-northwest at 12mph.\nThe NHC has warned that Elsa could bring "life-threatening" flash flooding and "significant" river flooding. (Image: NOAA)\nThe NHC has also issued a hurricane watch for a stretch of the Florida coast, from the Suwannee River to the An'}, 'finish_reason': 'length'}], 'usage': {'prompt_tokens': 30, 'total_tokens': 541, 'completion_tokens': 511}}, 200]
#
# Tropical Storm Elsa poised to make landfall in Florida
# prediction:
# [{'id': 'chatcmpl-HnnRVnVXd8kCQp8mNCuu6F', 'object': 'chat.completion', 'created': 1699365655, 'model': 'vicuna-13b-v1.5', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': 'as Category 1 hurricane\nTropical Storm Elsa is poised to make landfall in Florida as a Category 1 hurricane, with winds of up to 75 mph, the National Hurricane Center (NHC) said in its latest advisory on Wednesday.\nThe storm is expected to bring heavy rainfall, storm surges and flash flooding to parts of the state, the NHC said.\nElsa, which formed in the Caribbean Sea, has already caused flooding and power outages in the Dominican Republic and Haiti.\nThe NHC said the storm is moving north-northwest at 15 mph and is expected to make landfall in Florida on Wednesday evening.\nThe storm is forecast to move across the southeastern United States on Thursday and Friday, bringing heavy rainfall and the potential for flash flooding to parts of Georgia, South Carolina, North Carolina and Virginia.\nThe NHC warned of life-threatening flash flooding and urged residents in the affected areas to take necessary precautions.\nElsa is the earliest fifth-named storm on record to form in the Atlantic basin, breaking the previous record set by Don in 2005.'}, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 14, 'total_tokens': 290, 'completion_tokens': 276}}, 200]
#
# Weakening Elsa makes landfall but Florida spared significant damage
# prediction:
# [{'id': 'chatcmpl-3mhzzvLt6KkQLEYoB5iNT7', 'object': 'chat.completion', 'created': 1699365731, 'model': 'vicuna-13b-v1.5', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '\nMIAMI (AP) — Hurricane Elsa weakened to a tropical storm as it made landfall in Florida on Wednesday, but the storm still caused flooding and power outages in some areas as it moved across the state.\nThe National Hurricane Center said Elsa made landfall near Cedar Key with maximum sustained winds of 65 mph (105 kph). It was downgraded to a tropical storm later in the day as it moved across Florida.\nElsa’s center was expected to move across the eastern Gulf of Mexico on Thursday and approach the Florida Panhandle or southern Alabama on Friday.\nThe storm caused flooding and power outages in some areas, but Florida officials said the damage was not as bad as feared.\n“We are grateful that the impacts from Elsa have not been as severe as predicted,” Gov. Ron DeSantis said in a statement. “However, we are still experiencing heavy rain and strong winds in some areas, and we urge all Floridians to remain vigilant and take necessary precautions.”\nElsa was the earliest “E” storm on record to form in the Atlantic, developing on April 2. It caused minor damage in the Caribbean as it moved through the region last week.\nThe storm was expected to bring heavy rain and strong winds to parts of Florida, Georgia and South Carolina, and officials warned of the potential for flash flooding and power outages.\nThe National Hurricane Center issued a tropical storm warning for a large portion of Florida’s Gulf Coast, from the Suwannee River to the Ochlockonee River, as well as for parts of Georgia and South Carolina.\nElsa was the first hurricane of the 2021 Atlantic hurricane season, which officially began June 1. Forecasters had warned that the storm could bring heavy rain and strong winds to parts of Florida, Georgia and South Carolina, and officials urged residents to prepare for the possibility of power outages and flooding.\nThe storm was expected to bring heavy rain and strong winds to parts of Florida, Georgia and South Carolina, and officials warned of the potential for flash flooding and power outages.\nThe National Hurricane Center issued a tropical storm warning for a large portion of Florida’s Gulf Coast'}, 'finish_reason': 'length'}], 'usage': {'prompt_tokens': 15, 'total_tokens': 526, 'completion_tokens': 511}}, 200]
#
# Storm Elsa regains strength and becomes a HURRICANE
# prediction:
# [{'id': 'chatcmpl-3v7FuJcYVeTvGuT3ozRain', 'object': 'chat.completion', 'created': 1699365788, 'model': 'vicuna-13b-v1.5', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': 'as it heads towards the Caribbean\nStorm Elsa has regained strength and is now a Category 1 hurricane as it heads towards the Caribbean.\nThe National Hurricane Center (NHC) said the storm, which is currently around 1,240 miles (2,000km) east of the Windward Islands, has maximum sustained winds of 75mph (120km/h).\nIt is moving west at 22mph (35km/h) and is expected to continue on this path over the next few days.\nThe NHC said: “Some strengthening is forecast during the next 48 hours, and Elsa could become a major hurricane by Wednesday.”\nThe storm is currently not posing an immediate threat to any land, but the NHC has warned of the potential for heavy rainfall, flash flooding and mudslides in areas of higher ground.\nThe storm is expected to pass near or over the Windward Islands on Friday, with the potential for heavy rainfall and gusty winds.\nThe NHC has also warned of the potential for storm surge, coastal flooding and large and dangerous waves along the coasts of the Lesser Antilles.\nResidents in the affected areas are advised to monitor the progress of the storm and follow the advice of local authorities.\nPrevious articleBritish Airways to cut up to 10,000 jobs as it faces ‘worst crisis’ in its history\nNext articleBritish Airways to cut up to 10,000 jobs as it faces ‘worst crisis’ in its history'}, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 16, 'total_tokens': 381, 'completion_tokens': 365}}, 200]
#
# Tropical Storm Elsa makes landfall and batters Florida with 70mph winds as rescuers hunt for 9 missing in water
# prediction:
# [{'id': 'chatcmpl-3qTYdhhKuwC6obRWSNGY3a', 'object': 'chat.completion', 'created': 1699365845, 'model': 'vicuna-13b-v1.5', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '\nTropical Storm Elsa made landfall in Florida on Wednesday, bringing heavy rain and winds of up to 70mph as it moved across the state, causing power outages and flooding.\nThe storm, which was downgraded from a hurricane, hit the coast near Cedar Key, a small fishing town about 70 miles northwest of Tampa, at around 12.30pm local time.\nElsa, which had been a Category 1 hurricane earlier in the day, caused flooding and power outages in parts of the state, with more than 100,000 homes and businesses without electricity.\nThe storm also caused problems for people trying to get to work, with several school districts in the Tampa Bay area canceling classes for the day.\nThe National Hurricane Center said Elsa was expected to move across northern Florida and into Georgia on Wednesday night, before moving into the Carolinas on Thursday.\nThe storm was expected to weaken as it moves inland, but it could still bring heavy rain and flash flooding to parts of the southeast.\nMeanwhile, rescue crews in Florida were searching for nine people who were reported missing in the water, including four who were swept away by a strong current in a flooded creek in Pasco County.\nThe search for the missing people was ongoing, with authorities warning residents to stay away from flooded areas and to be cautious of rising waters.\nElsa, which formed in the Caribbean Sea earlier this month, was the earliest E-named storm on record to form in the Atlantic basin.\nIt caused damage and power outages in the Caribbean before making its way to Florida.'}, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 33, 'total_tokens': 414, 'completion_tokens': 381}}, 200]
#
# Tropical Storm Elsa : Cuba reels as storm moves towards Florida
# prediction:
# [{'id': 'chatcmpl-3VFLYC86G69r9A2F5bygBX', 'object': 'chat.completion', 'created': 1699365906, 'model': 'vicuna-13b-v1.5', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': "\nHAVANA, July 7 (APP - Agencia Prensa Latina) The Cuban capital on Wednesday was still reeling from the impact of Tropical Storm Elsa, which hit the island overnight, as the storm continued its path towards the United States, where it is expected to make landfall in Florida later in the day.\nThe storm, which brought heavy rains and strong winds to Cuba, caused flooding and power outages in several areas of Havana, according to local media reports.\nIn the eastern province of Guantanamo, Elsa caused the death of a 65-year-old man who was swept away by a river, while in the central province of Villa Clara, a 45-year-old woman died after being struck by a falling tree.\nThe Cuban government has activated its emergency response system and deployed personnel and resources to affected areas to assist in the recovery efforts.\nElsa, which was downgraded to a tropical storm after passing over Cuba, is currently moving northwest at a speed of 22 kilometers per hour, with maximum sustained winds of 110 kilometers per hour, according to the National Hurricane Center (NHC).\nThe NHC has issued a hurricane warning for the Florida Keys and the west coast of Florida from Bonita Beach to the Ochlockonee River, as well as a tropical storm warning for the east coast of Florida from Jupiter Inlet to Sebastian Inlet.\nFlorida Governor Ron DeSantis has declared a state of emergency in anticipation of the storm's impact, and has urged residents to prepare for potential flooding, power outages, and other hazards.\nElsa is the earliest fifth-named storm on record in the Atlantic basin, and comes just over a month after the start of the official hurricane season on June 1."}, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 15, 'total_tokens': 427, 'completion_tokens': 412}}, 200]
#
# Tropical Storm Elsa takes aim at Florida after passing Cuba
# prediction:
# [{'id': 'chatcmpl-YtojLeEZN2YkyHfUd69eok', 'object': 'chat.completion', 'created': 1699365960, 'model': 'vicuna-13b-v1.5', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '\nTropical Storm Elsa is moving northward over the southeastern Gulf of Mexico after passing over western Cuba, and forecasters say it could make landfall in Florida as a hurricane.\nThe National Hurricane Center in Miami said early Wednesday that Elsa was centered about 105 miles (170 kilometers) south-southwest of Tampa, Florida, and moving north at 14 mph (22 kph). It had maximum sustained winds of 65 mph (105 kph).\nThe storm is expected to strengthen before making landfall in Florida on Wednesday, possibly in the Big Bend area, which includes the cities of Tampa and St. Petersburg.\nElsa hit Cuba as a tropical storm on Tuesday, causing flooding and power outages but no reports of serious injuries or deaths.\nThe storm earlier caused heavy rain and flooding in the Dominican Republic and Haiti, where at least 11 people died.\nThe Hurricane Center warned of a storm surge of up to 4 feet (1.2 meters) along the coast of Florida, and forecasters said Elsa could bring 3 to 6 inches (7.5 to 15.2 centimeters) of rain to parts of Florida, with isolated maximum amounts of 8 inches (20.3 centimeters).\nElsa is the earliest fifth-named storm on record in the Atlantic basin, which includes the Caribbean Sea and the Gulf of Mexico. The previous record was held by Don in 2005, which formed on July 26.'}, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 13, 'total_tokens': 375, 'completion_tokens': 362}}, 200]
#
# Tropical Storm Elsa gaining strength as it lashes Florida Keys
# prediction:
# [{'id': 'chatcmpl-9RPwmZenZRHfUXGgJNAvra', 'object': 'chat.completion', 'created': 1699365995, 'model': 'vicuna-13b-v1.5', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': "\nTropical Storm Elsa is gaining strength as it lashes the Florida Keys with heavy rain and winds, prompting warnings of flash flooding and coastal flooding.\nThe National Hurricane Center said the storm's maximum sustained winds have increased to near 60 mph (95 kph) with higher gusts. Elsa is moving north-northwest at 12 mph (19 kph).\nThe storm is expected to bring 3 to 6 inches (7.6 to 15.2 centimeters) of rain to the Florida Keys and South Florida, with isolated amounts of up to 10 inches (25.4 centimeters) possible.\nElsa is the earliest fifth-named storm on record in the Atlantic basin, beating out the previous record held by Don in 2003.\nThe storm is forecast to move near or over the west coast of Florida later in the day, bringing the potential for heavy rain and winds to the state's Gulf Coast."}, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 17, 'total_tokens': 249, 'completion_tokens': 232}}, 200]
#
# Tropical Storm Elsa approaches Florida after 180 , 000 evacuated in Cuba
# prediction:
# [{'id': 'chatcmpl-34mabjkkXZFVTTdWDuySUw', 'object': 'chat.completion', 'created': 1699366071, 'model': 'vicuna-13b-v1.5', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '\nTropical Storm Elsa, which has already caused flooding and power outages in the Caribbean, is expected to hit Florida\'s Gulf Coast on Wednesday, with Tampa Bay and the Florida Keys among the areas under threat, forecasters said.\nThe storm, which has maximum sustained winds of 60 miles per hour (95 km per hour), was about 110 miles (175 km) south-southeast of Tampa, Florida, as of 8 a.m. ET (1200 GMT), the National Hurricane Center (NHC) said.\nIt was moving north-northwest at 12 miles per hour (19 km per hour), the NHC said.\nA hurricane watch was in effect for the lower Florida Keys, while a tropical storm warning was in effect for the west coast of Florida from the Suwannee River southward to Flamingo, the NHC said.\nElsa, which formed in the Caribbean Sea on Saturday, caused heavy rains and flooding in Puerto Rico and the Dominican Republic, as well as power outages in Cuba, where more than 180,000 people were evacuated, according to local media.\nThe storm is expected to bring heavy rainfall, flash flooding and possible tornadoes to parts of Florida, forecasters said.\n"This storm is going to bring a lot of rain, and that\'s going to be the biggest concern," said Dennis Feltgen, a meteorologist with the NHC.\n"We\'re looking at 3 to 6 inches (7.5 to 15 cm) of rain, with isolated amounts up to 10 inches (25 cm) in some areas," he said.\nFlorida Governor Ron DeSantis declared a state of emergency on Monday, allowing the state to mobilize resources and prepare for the storm.\nThe Tampa Bay area, which was hit by Hurricane Irma in 2017, has already seen heavy rain and flooding this week, with some areas receiving more than 10 inches (25 cm) of rain, according to the National Weather Service.\nThe NHC said Elsa could bring additional rainfall to the region, which is still recovering from the effects of H'}, 'finish_reason': 'length'}], 'usage': {'prompt_tokens': 23, 'total_tokens': 534, 'completion_tokens': 511}}, 200]
#
# Tropical Storm Elsa lashes Florida Keys as conditions worsen
# prediction:
# [{'id': 'chatcmpl-3DRoPErVyVKkuGxajvQQ2b', 'object': 'chat.completion', 'created': 1699366149, 'model': 'vicuna-13b-v1.5', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': "in the Caribbean\nTropical Storm Elsa lashed the Florida Keys on Sunday, as the storm's winds and rain spread misery across the Caribbean and forecasters warned that conditions would worsen in some areas.\nThe National Hurricane Center said Elsa's maximum sustained winds were near 60 mph (95 kph) as it moved north-northwest at 12 mph (19 kph). The storm was centered about 35 miles (55 kilometers) south-southwest of Key West, Florida, and was forecast to move across the Florida Keys and into the Gulf of Mexico on Sunday.\nA tropical storm warning was in effect for the lower Florida Keys from Key West to the Dry Tortugas, while a tropical storm watch was in effect for the west coast of Florida from Bonita Beach to the Ochlockonee River.\nElsa was expected to bring heavy rainfall to the Florida Keys and parts of the Florida Peninsula, with flash flooding possible, the hurricane center said.\nMeanwhile, the storm was already causing problems in the Caribbean, where it had earlier passed through the southern Windward Islands and the eastern coast of Nicaragua.\nIn Barbados, the national weather service reported heavy rainfall and gusty winds, while in St. Vincent and the Grenadines, the prime minister's office said the storm caused flooding and landslides that left at least one person dead.\nIn Haiti, authorities reported heavy rain and strong winds, with the country's civil protection agency urging people to be prepared for possible flooding and landslides.\nThe storm was also affecting the Dominican Republic, where heavy rain and strong winds were reported in the eastern part of the country.\nElsa is the earliest fifth-named storm on record in the Atlantic basin, according to Philip Klotzbach, a research scientist at Colorado State University. The previous record was held by Don in 2003, which formed on July 22.\nThe 2021 Atlantic hurricane season officially began on June 1 and runs through Nov. 30. It's already been an active season, with several named storms forming before the official start date."}, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 17, 'total_tokens': 527, 'completion_tokens': 510}}, 200]
#
# Hurricane Elsa : Storm heads towards Haiti and the Dominican Republic on possible path to Cuba and Florida
# prediction:
# [{'id': 'chatcmpl-GfGnnhDG6QJXVtxs3XdhEK', 'object': 'chat.completion', 'created': 1699366226, 'model': 'vicuna-13b-v1.5', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '\nHurricane Elsa is moving towards Haiti and the Dominican Republic, with forecasters warning of heavy rainfall and strong winds as it heads towards Cuba and potentially Florida.\nThe storm, which was downgraded to a Category 1 hurricane on Wednesday, is expected to bring 50mph (80km/h) winds and up to 10in (25cm) of rain to the region, the US National Hurricane Centre (NHC) said.\nIt is currently around 125 miles (200km) south-east of the Haitian capital, Port-au-Prince, and is moving west at 15mph (24km/h).\nThe NHC said Elsa could strengthen again before reaching Cuba and then move on to Florida over the weekend.\nThe storm has already caused flooding and power outages in some Caribbean islands, including Barbados and St Lucia.\nElsa is the earliest fifth-named storm on record, and comes as the Atlantic hurricane season is already shaping up to be above average.\nThe NHC said Elsa was expected to bring “dangerous storm surge, rainfall, and wind impacts” to Haiti and the Dominican Republic, as well as Cuba.\n“Preparations should be rushed to completion in all areas,” it added.\nThe storm is expected to bring heavy rainfall to the Dominican Republic, Haiti, and eastern Cuba, with flash flooding and landslides possible in some areas.\nElsa is the fifth named storm of the Atlantic hurricane season, which officially began on 1 June and runs until 30 November.\nThe NHC said the storm was expected to bring “dangerous storm surge, rainfall, and wind impacts” to Haiti and the Dominican Republic, as well as Cuba\nThe storm has already caused flooding and power outages in some Caribbean islands, including Barbados and St Lucia\nElsa is the earliest fifth-named storm on record, and comes as the Atlantic hurricane season is already shaping up to be above average\nThe NHC said Elsa could strengthen again before reaching Cuba and then move on to Florida over the weekend\nThe storm is expected to bring heavy rainf'}, 'finish_reason': 'length'}], 'usage': {'prompt_tokens': 25, 'total_tokens': 536, 'completion_tokens': 511}}, 200]
#
# Hurricane Elsa path tracker : Where will storm hit and will it reach Florida ?
# prediction:
# [{'id': 'chatcmpl-AeaZRdEJu8xnmhCwNAdsew', 'object': 'chat.completion', 'created': 1699366302, 'model': 'vicuna-13b-v1.5', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '2021\nHurricane Elsa path tracker : Where will storm hit and will it reach Florida? 2021\nHurricane Elsa path tracker : Where will storm hit and will it reach Florida? 2021. Hurricane Elsa is the first hurricane of the 2021 Atlantic hurricane season. It is a Category 1 hurricane with maximum sustained winds of 75 mph. The storm is currently moving west-northwest at 29 mph and is expected to continue on this track for the next few days. The storm is forecast to pass near or over portions of the Lesser Antilles on Wednesday and Thursday, and then move into the eastern Caribbean Sea on Friday.\nHurricane Elsa is expected to bring heavy rainfall and strong winds to the Lesser Antilles and eastern Caribbean Sea. The storm is also expected to bring rough surf and dangerous marine conditions. Residents in the affected areas should prepare for the possibility of flash flooding, mudslides, and power outages.\nHurricane Elsa is forecast to strengthen over the next few days, and it could become a Category 2 hurricane before it reaches the Lesser Antilles. The storm is expected to weaken slightly as it moves through the Caribbean Sea, but it will still pose a threat to the region.\nThe National Hurricane Center (NHC) is closely monitoring Hurricane Elsa and will provide updates on its path and intensity as the storm progresses. Residents in the affected areas should stay tuned to the latest forecasts and warnings from the NHC and local officials.\nHurricane Elsa path tracker\nHurricane Elsa is expected to move west-northwest over the next few days, and it is forecast to pass near or over portions of the Lesser Antilles on Wednesday and Thursday. The storm is then expected to move into the eastern Caribbean Sea on Friday.\nThe NHC is forecasting that Hurricane Elsa will continue on this track for the next few days, and it is expected to strengthen over the next 48 hours. The storm is forecast to weaken slightly as it moves through the Caribbean Sea, but it will still pose a threat to the region.'}, 'finish_reason': 'length'}], 'usage': {'prompt_tokens': 21, 'total_tokens': 532, 'completion_tokens': 511}}, 200]
#
# Storm Elsa has become a hurricane , the first of the season , and is barreling towards Florida
# prediction:
# [{'id': 'chatcmpl-p9mJ24zw8KPsk6CuH5rqqQ', 'object': 'chat.completion', 'created': 1699366361, 'model': 'vicuna-13b-v1.5', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '.\nThe National Hurricane Center said Elsa has maximum sustained winds of 75 mph (120 kph) and is moving northwest at 13 mph (20 kph).\nForecasters say Elsa is expected to strengthen into a major hurricane before it makes landfall in Florida on Wednesday.\nThe storm is currently located about 335 miles (540 km) southeast of Miami, Florida.\nA hurricane warning is in effect for the lower Florida Keys and the Florida Peninsula from Jupiter Inlet southward to the border of the Florida-Georgia border.\nA tropical storm warning is in effect for the east coast of Florida north of Jupiter Inlet to the Flagler-Volusia County line.\nA storm surge warning is in effect for the lower Florida Keys and the Florida Peninsula from Jupiter Inlet southward to the border of the Florida-Georgia border.\nA hurricane watch is in effect for the upper Florida Keys and for the west coast of Florida from Jupiter Inlet southward to the border of the Florida-Georgia border.\nA tropical storm watch is in effect for the west coast of Florida north of Jupiter Inlet to the Flagler-Volusia County line.\nFlorida Governor Ron DeSantis has declared a state of emergency in all 67 counties in the state.\nThe National Hurricane Center is urging residents in the affected areas to prepare for dangerous storm surge, heavy rainfall, and strong winds.\nElsa is the earliest fifth-named storm on record in the Atlantic basin, surpassing the previous record held by Hurricane Alpha in 2020, which formed on July 31.'}, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 24, 'total_tokens': 419, 'completion_tokens': 395}}, 200]
#
# Storm Elsa : How is it evolving and how far is it from Florida ?
# prediction:
# [{'id': 'chatcmpl-GrunFsXd9G2jtLbegwKMCt', 'object': 'chat.completion', 'created': 1699366440, 'model': 'vicuna-13b-v1.5', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '🌪️🌊🌊🌊\nStorm Elsa : How is it evolving and how far is it from Florida? 🌪️🌊🌊🌊\nStorm Elsa : How is it evolving and how far is it from Florida? 🌪️🌊🌊🌊\nStorm Elsa : How is it evolving and how far is it from Florida? 🌪️🌊🌊🌊\nStorm Elsa : How is it evolving and how far is it from Florida? 🌪️🌊🌊🌊\nStorm Elsa : How is it evolving and how far is it from Florida? 🌪️🌊🌊🌊\nStorm Elsa : How is it evolving and how far is it from Florida? 🌪️🌊🌊🌊\nStorm Elsa : How is it evolving and how far is it from Florida? 🌪️🌊🌊🌊\nStorm Elsa : How is it evolving and how far is it from Florida? 🌪️🌊🌊🌊\nStorm Elsa : How is it evolving and how far is it from Florida? 🌪️🌊🌊🌊\nStorm Elsa : How is it evolving and how far is it from Florida? 🌪️🌊🌊🌊\nStorm Elsa : How is it evolving and how far is it from Florida? 🌪️🌊🌊🌊\nStorm Elsa : How is it evolving and how far is it from Florida? 🌪️🌊🌊🌊\nStorm Elsa : How is it evolving and how far is it from Florida? 🌪️🌊🌊🌊\nStorm Elsa : How is it evolving and how far'}, 'finish_reason': 'length'}], 'usage': {'prompt_tokens': 19, 'total_tokens': 530, 'completion_tokens': 511}}, 200]
#
# Tropical storm Elsa batters Cuban and Florida coasts - Israel National News
# prediction:
# ...
#
# Hurricane Elsa Path : Tropical storm Elsa gaining strength , lashing Florida Keys | World News
# prediction:
# [{'id': 'chatcmpl-LDiS9nfrssKDPzk6ZGzK8n', 'object': 'chat.completion', 'created': 1699368034, 'model': 'vicuna-13b-v1.5', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '\nTropical Storm Elsa lashed the Florida Keys on Wednesday as it continued on a path toward the U.S.S. mainland, where forecasters warned it could become a hurricane before making landfall in the coming days.\nThe National Hurricane Center said Elsa’s maximum sustained winds had increased to near 60 mph (95 kph) with higher gusts. The storm was centered about 90 miles (145 kilometers) south-southwest of Key West and moving north-northwest at 12 mph (19 kph).\nA tropical storm warning was in effect for the lower Florida Keys from Key West to the Dry Tortugas, while a tropical storm watch was in effect for the west coast of Florida from Anclote Key to the Ochlockonee River.\nElsa was expected to bring heavy rainfall to the Keys and parts of the Florida peninsula, with flash flooding possible. The storm was forecast to move across the eastern Gulf of Mexico and approach the north-central Gulf Coast by late Friday or Saturday.\nThe National Hurricane Center said Elsa could become a hurricane by Thursday or Friday.\n“Interests along the north-central Gulf Coast should monitor the progress of this system and ensure they are ready for the possibility of tropical storm or hurricane conditions later this week,” the center said in an advisory.\nElsa was the earliest fifth-named storm on record in the Atlantic basin, which includes the Caribbean Sea and the Gulf of Mexico, according to Colorado State University hurricane researcher Phil Klotzbach. The previous record was held by the 2005 season, which had four named storms by this time.\nThe storm had already caused flooding and power outages in the Caribbean, where it made landfall in Barbados as a tropical storm on Monday before moving on to St. Lucia, Martinique and other islands.\nPrevious articleHurricane Elsa Path : Tropical storm Elsa gaining strength, lashing Florida Keys | World News\nNext articleHurricane Elsa Path : Tropical storm Elsa gaining strength, lashing Florida Keys | World News'}, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 26, 'total_tokens': 524, 'completion_tokens': 498}}, 200]
#
# Tropical Storm Elsa gaining strength , could become hurricane
# prediction:
# [{'id': 'chatcmpl-otzReQgjV52gDLGfTXjzxz', 'object': 'chat.completion', 'created': 1699368091, 'model': 'vicuna-13b-v1.5', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': 'by Friday\nMIAMI (AP) — Tropical Storm Elsa is gaining strength as it moves across the Caribbean and could become a hurricane by Friday, forecasters said Wednesday.\nThe U.S. National Hurricane Center said Elsa’s maximum sustained winds increased to near 50 mph (85 kph) and the storm was centered about 115 miles (185 kilometers) east-southeast of the Nicaraguan coast. It was moving west-northwest at 22 mph (35 kph).\nA hurricane watch was issued for the coast of Nicaragua from the border with Honduras to the Costa Rica-Nicaragua border. A tropical storm warning was in effect for the coast of Honduras from the border with Guatemala to the border with Nicaragua.\nElsa is the earliest fifth-named storm on record in the Atlantic basin, which includes the Caribbean Sea and the Gulf of Mexico, the hurricane center said. The previous record was held by Don in 2003, which formed on July 21.\nForecasters said Elsa could become a hurricane by Friday and could bring heavy rainfall to parts of Central America and the Cayman Islands over the weekend.\nThe storm is expected to move over the southeastern Bahamas on Thursday and then move near or over the east coast of the Florida peninsula on Friday, the hurricane center said.\nMeanwhile, the remnants of Tropical Storm Dolores were moving across the eastern Pacific and were expected to become a tropical depression later in the day. The system was not expected to threaten any land.'}, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 15, 'total_tokens': 399, 'completion_tokens': 384}}, 200]
#
# Tropical storm Elsa set to exit Cuba , take aim at Florida
# prediction:
# [{'id': 'chatcmpl-YsxCdWkwSenjxfC9ZksX5h', 'object': 'chat.completion', 'created': 1699368155, 'model': 'vicuna-13b-v1.5', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': 'Keys\nTropical Storm Elsa is expected to exit Cuba and head towards the Florida Keys, where it could make landfall as a hurricane on Wednesday, forecasters said.\nThe National Hurricane Center (NHC) said Elsa was located about 105 miles (170 km) southeast of Havana, Cuba, and was moving northwest at 13 mph (20 km/h) on Tuesday morning.\nThe storm had maximum sustained winds of 60 mph (95 km/h) and was expected to strengthen slightly before making landfall in the Keys, the NHC said.\nA hurricane warning was in effect for the Lower Florida Keys from Craig Key westward to the Dry Tortugas, and a tropical storm warning was in effect for the Upper Florida Keys from Ocean Reef southward to Craig Key.\nElsa is the earliest fifth-named storm on record to form in the Atlantic basin, the NHC said. The previous record was held by Edouard, which formed on Aug. 5, 2005.\nThe storm is expected to bring heavy rainfall and strong winds to the Keys, as well as parts of southern Florida, including Miami and Fort Lauderdale.\nFlorida Governor Ron DeSantis declared a state of emergency on Monday, allowing the state to prepare for potential impacts from the storm.\n“We urge all Floridians to make sure they have their emergency preparedness plans in place and to monitor the path of this storm closely,” DeSantis said in a statement.\nElsa is the first named storm of the 2021 Atlantic hurricane season, which officially began on June 1. The season is expected to be above average, with forecasters predicting 13 to 20 named storms, of which 6 to 10 could become hurricanes.'}, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 15, 'total_tokens': 445, 'completion_tokens': 430}}, 200]
#
# USA News Headlines Today Live Updates : Tropical storm Elsa gaining strength , lashing Florida Keys
# prediction:
# [{'id': 'chatcmpl-efr84SvehDcYMBigVzhTjW', 'object': 'chat.completion', 'created': 1699368216, 'model': 'vicuna-13b-v1.5', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '\nTropical storm Elsa gaining strength, lashing Florida Keys\nTropical storm Elsa gaining strength, lashing Florida Keys.\nTropical Storm Elsa is gaining strength as it lashes the Florida Keys, prompting warnings of heavy rainfall and dangerous storm surges.\nThe National Hurricane Center said Elsa’s maximum sustained winds had increased to near 60 mph (95 kph) with higher gusts as it moved northwest at 12 mph (19 kph).\nThe storm was centered about 35 miles (55 kilometers) south-southeast of Key West, Florida, and was moving north-northwest.\nA tropical storm warning is in effect for the lower Florida Keys from Key West to the Dry Tortugas, and a tropical storm watch is in effect for the west coast of Florida from Bonita Beach to the Ochlockonee River.\nThe National Hurricane Center said Elsa could bring 3 to 6 inches (75 to 150 millimeters) of rain to the Florida Keys and South Florida, with isolated maximum amounts of 8 inches (200 millimeters).\nThe storm is expected to move near or over the west coast of Florida on Wednesday and Wednesday night, and then move inland over the Florida Panhandle and southern Georgia on Thursday.\nResidents in the affected areas are advised to prepare for possible power outages, heavy rainfall, and dangerous storm surges.\nElsa is the earliest fifth-named storm on record in the Atlantic basin, beating the previous record set by Don in 2003.\nThe 2021 Atlantic hurricane season officially began on June 1 and runs through November 30.'}, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 25, 'total_tokens': 427, 'completion_tokens': 402}}, 200]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[78], line 3
#       1 unique_messages = df.loc[df['cluster_25_75'] == 2].title.unique()
#       2 for title in unique_messages:
# ----> 3     prediction = run_vicuna_ee(title)
#       4     print(title)
#       5     print(f"prediction:")
#
# Cell In[77], line 15, in run_vicuna_ee(message)
#      13 url = 'https://turbo.skynet.coypu.org/'
#      14 json_obj = {'messages': message, "key": "M7ZQL9ELMSDXXE86", "temperature": 0.1}
# ---> 15 x = requests.post(url, json = json_obj)
#      16 try:
#      17     prediction = x.json()
#
# File ~/opt/anaconda3/envs/ed/lib/python3.9/site-packages/requests/api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)
#     112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File ~/opt/anaconda3/envs/ed/lib/python3.9/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/opt/anaconda3/envs/ed/lib/python3.9/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/opt/anaconda3/envs/ed/lib/python3.9/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/opt/anaconda3/envs/ed/lib/python3.9/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File ~/opt/anaconda3/envs/ed/lib/python3.9/site-packages/urllib3/connectionpool.py:714, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     711     self._prepare_proxy(conn)
#     713 # Make the request on the httplib connection object.
# --> 714 httplib_response = self._make_request(
#     715     conn,
#     716     method,
#     717     url,
#     718     timeout=timeout_obj,
#     719     body=body,
#     720     headers=headers,
#     721     chunked=chunked,
#     722 )
#     724 # If we're going to release the connection in ``finally:``, then
#     725 # the response doesn't need to know about the connection. Otherwise
#     726 # it will also try to release it and we'll have a double-release
#     727 # mess.
#     728 response_conn = conn if not release_conn else None
#
# File ~/opt/anaconda3/envs/ed/lib/python3.9/site-packages/urllib3/connectionpool.py:466, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     461             httplib_response = conn.getresponse()
#     462         except BaseException as e:
#     463             # Remove the TypeError from the exception chain in
#     464             # Python 3 (including for exceptions like SystemExit).
#     465             # Otherwise it looks like a bug in the code.
# --> 466             six.raise_from(e, None)
#     467 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     468     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/opt/anaconda3/envs/ed/lib/python3.9/site-packages/urllib3/connectionpool.py:461, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     458 except TypeError:
#     459     # Python 3
#     460     try:
# --> 461         httplib_response = conn.getresponse()
#     462     except BaseException as e:
#     463         # Remove the TypeError from the exception chain in
#     464         # Python 3 (including for exceptions like SystemExit).
#     465         # Otherwise it looks like a bug in the code.
#     466         six.raise_from(e, None)
#
# File ~/opt/anaconda3/envs/ed/lib/python3.9/http/client.py:1377, in HTTPConnection.getresponse(self)
#    1375 try:
#    1376     try:
# -> 1377         response.begin()
#    1378     except ConnectionError:
#    1379         self.close()
#
# File ~/opt/anaconda3/envs/ed/lib/python3.9/http/client.py:320, in HTTPResponse.begin(self)
#     318 # read until we get a non-100 response
#     319 while True:
# --> 320     version, status, reason = self._read_status()
#     321     if status != CONTINUE:
#     322         break
#
# File ~/opt/anaconda3/envs/ed/lib/python3.9/http/client.py:281, in HTTPResponse._read_status(self)
#     280 def _read_status(self):
# --> 281     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     282     if len(line) > _MAXLINE:
#     283         raise LineTooLong("status line")
#
# File ~/opt/anaconda3/envs/ed/lib/python3.9/socket.py:704, in SocketIO.readinto(self, b)
#     702 while True:
#     703     try:
# --> 704         return self._sock.recv_into(b)
#     705     except timeout:
#     706         self._timeout_occurred = True
#
# File ~/opt/anaconda3/envs/ed/lib/python3.9/ssl.py:1242, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1238     if flags != 0:
#    1239         raise ValueError(
#    1240           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1241           self.__class__)
# -> 1242     return self.read(nbytes, buffer)
#    1243 else:
#    1244     return super().recv_into(buffer, nbytes, flags)
#
# File ~/opt/anaconda3/envs/ed/lib/python3.9/ssl.py:1100, in SSLSocket.read(self, len, buffer)
#    1098 try:
#    1099     if buffer is not None:
# -> 1100         return self._sslobj.read(len, buffer)
#    1101     else:
#    1102         return self._sslobj.read(len)
#
# KeyboardInterrupt:
